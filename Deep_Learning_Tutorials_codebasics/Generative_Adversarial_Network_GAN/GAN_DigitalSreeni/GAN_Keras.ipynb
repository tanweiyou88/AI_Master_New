# %% [markdown]
# # Generative Adversarial Networks (GAN) using Keras in Python
#
# Link to the Youtube video tutorial: https://www.youtube.com/watch?v=Mng57Tj18pc&list=PLZsOBAyNTZwboR4_xj-n3K6XBTweC4YVD&index=2&t=129s
#
# <br />
#
# **Concept of the Generative Adversarial Networks (GAN) model:**
# 1) <img src="hidden\photo1.png" alt="This image is a representation of the simple neural network" style="width: 400px;"/>  <br />
# 2) <img src="hidden\photo2.png" alt="This image is a representation of the simple neural network" style="width: 400px;"/>  <br />
#     1) When we train the Discriminator (discriminator network), the Generator (generator network) must be fixed (means the parameters [weights and biases] of the generator network are not updated (learned) with the cost function value of each epoch). We do this by only using the discriminator network (not the GAN model) to train the discriminator network.
#     2)  When we train the Generator (generator network), the Discriminator (discriminator network) must be fixed (means the parameters [weights and biases] of the discriminator network are not updated (learned) with the cost function value of each epoch). We do this by setting the discriminator network as not trainable when creating the GAN model, then we train the generator network by using the GAN model.
# 3) <img src="hidden\photo3.png" alt="This image is a representation of the simple neural network" style="width: 400px;"/>  <br />
# 4) <img src="hidden\photo4.png" alt="This image is a representation of the simple neural network" style="width: 400px;"/>  <br />

# %%
from keras.datasets import mnist # MNIST is the handwritten digit dataset, containing class (handwritten digit) 0 to 9. Each handwritten digit image has dimension of (28,28,1).
from keras.layers import Input, Dense, Reshape, Flatten
from keras.layers import BatchNormalization
from keras.layers.advanced_activations import LeakyReLU
from keras.models import Sequential, Model
from keras.optimizers import adam_v2
import matplotlib.pyplot as plt
import numpy as np
import os
import datetime

# %% [markdown]
# # Define the image dimensions/shape involved in the GAN model

# %%
# Define the image dimensions/shape (which is the generator network output layer size & the discriminator network input layer size). We should define the image dimensions same as the dimensions of the real images (from the dataset)
# Large images take too much time and resources.
img_rows = 28 # the dimension of the real images (from the dataset)
img_cols = 28 # the dimension of the real images (from the dataset)
channels = 1 # grayscale, the dimension of the real images (from the dataset)
img_shape = (img_rows, img_cols, channels) # so, the image shape we defined has dimension of 28 x 28 pixels, in grayscale. Equivalent to (28,28,1).

# %% [markdown]
# # Define the function to group the defined layers for the generator network into an object with training/inference features
#
# 1) The generator network here consists of only 3 hidden layers as dense layer. (number of neurons in 2nd hidden (dense) layer) > (number of neurons in 1st hidden (dense) layer); (number of neurons in 3rd hidden (dense) layer) > (number of neurons in 2nd hidden (dense) layer)
# 2) In short, for the generator network in a GAN model:
#     1) The further the hidden (dense) layer, the larger the number of neurons in the hidden (dense) layer
#     2) It accepts 1D array of noise/latent vector (seed) as the input, then it transforms the input into larger 1D array and reshape the generated larger 1D array into 2D array (so that an image is formed). You can treate element in the 1D array as a feature.
# 3) We don't use compile() to compile the generator network because we train the generator network by using the GAN model (not the generator network itself only).

# %%
# Given input of noise (latent) vector, the Generator produces an image.
def build_generator():

    noise_shape = (100,) #1D array of size 100 (latent vector / noise)

# Define your generator network (model)
# Here we are only using Dense layers. But network can be complicated based on the application. For example, you can use VGG for super res. GAN. 
# Usually, dense layer is used for hidden layer & output layer of a neural network.
# The generator network here consists of only 3 hidden layers as dense layer. (number of neurons in 2nd hidden (dense) layer) > (number of neurons in 1st hidden (dense) layer); (number of neurons in 3rd hidden (dense) layer) > (number of neurons in 2nd hidden (dense) layer)       
# In short, for a generator network in GAN:
# 1) The further the hidden (dense) layer, the larger the number of neurons in the hidden (dense) layer
# 2) It accepts 1D array of noise/latent vector (seed) as the input, then it transforms the input into larger 1D array and reshape the generated larger 1D array into 2D array (so that an image is formed). You can treate element in the 1D array as a feature.

    # Define the structure of the generator network:
    model = Sequential() # the generator network is built using sequential model

    model.add(Dense(256, input_shape=noise_shape)) # The 1st hidden (dense) layer of the generator network (2nd layer of the generator network).
    model.add(LeakyReLU(alpha=0.2)) # alpha is a small positive value (typically set to 0.01 by default) that allows a small, non-zero gradient when the input is negative. This helps to mitigate the “dying ReLU” problem, where neurons can sometimes get stuck during training and stop learning
    model.add(BatchNormalization(momentum=0.8)) # momentum refers to how fast it actually trains
    model.add(Dense(512)) # The 2nd hidden (dense) layer of the generator network 
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Dense(1024)) # The 3rd hidden (dense) layer of the generator network
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization(momentum=0.8))
    
    model.add(Dense(np.prod(img_shape), activation='tanh')) # The output (dense) layer of the generator network. The number of neurons in the output layer = np.prod(img_shape). So this output layer will produce a 1D array/vector with dimension of np.prod(img_shape) (means the output vector consists of np.prod(img_shape) elements)
    model.add(Reshape(img_shape)) # The reshape layer, that reshapes the output vector (the 1D array containing np.prod(img_shape) elements) into a vector of 2D array that has dimension of img_shape elements

    model.summary() # print the summary of the generator network

    noise = Input(shape=noise_shape) # The input layer of the generator network (the 1st layer of the generator network). The input layer that has noise_shape number of neurons (so that each neuron in the input layer accepts 1 element/feature of the noise/latent vector). Since we are using the older Keras version to build the model, we need to explicitly define the input layer using Input(). Else, the model summary cannot be executed. Reference: https://enjoymachinelearning.com/blog/keras-input-shape/
    img = model(noise) # The variable img stores a generated image (fake data), produced by the generator network. model(x) means use the defined model (generator network) to produce the output, by taking x as the input.

    return Model(noise, img) # Grouping the layers defined for the generator network into an object with training/inference features), by specifing the variable noise as its input and the variable img as its output.


# Alpha — α is a hyperparameter which controls the underlying value to which the function saturates negatives network inputs.
# Momentum — Speed up the training

# %% [markdown]
# # Define the function to group the defined layers for the discriminator network into an object with training/inference features
#
# 1) The discriminator network here consists of only 2 hidden layers as dense layer. (number of neurons in 2nd hidden (dense) layer) > (number of neurons in 1st hidden (dense) layer)
# 2) In short, for the discriminator network in a GAN model:
#     1) The further the hidden (dense) layer, the smaller the number of neurons in the hidden (dense) layer
#     2) It accepts 1D array of noise/latent vector (seed) as the input, then it transforms the input into larger 1D array and reshape the generated larger 1D array into 2D array (so that an image is formed). You can treate element in the 1D array as a feature.

# %%
# Given an input image, the Discriminator (discriminator network) outputs the likelihood of the image being real.
# Binary classification - true or false (we're calling it validity)
# A discriminator is just like a binary classifier

def build_discriminator():

# Define your discriminator network (model)
# Here we are only using Dense layers. 
# Usually, dense layer is used for hidden layer & output layer of a neural network.
# The discriminator network here consists of only 2 hidden layers as dense layer. (number of neurons in 2nd hidden (dense) layer) > (number of neurons in 1st hidden (dense) layer)
# In short, for a discriminator network in GAN:
# 1) The further the hidden (dense) layer, the smaller the number of neurons in the hidden (dense) layer
# 2) It accepts 1D array of noise/latent vector (seed) as the input, then it transforms the input into larger 1D array and reshape the generated larger 1D array into 2D array (so that an image is formed). You can treate element in the 1D array as a feature.

    # Define the structure of the discriminator network:
    model = Sequential() # the discriminator network is built using sequential model

    model.add(Flatten(input_shape=img_shape)) # The flatten layer (2nd layer of the discriminator network). Since the discriminator network receives a 2D image as the input, we need this flatten layer to flatten the 2D image (features/pixel in 2D) into 1D array (features/pixel in 1D)
    model.add(Dense(512)) # The 1st hidden (dense) layer of the discriminator network (3rd layer of the discriminator network).
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(256)) # The 2nd hidden (dense) layer of the discriminator network.
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(1, activation='sigmoid')) # The output (dense) layer of the discriminator network. The number of neurons in the output layer is only 1, because the output of the discriminator network is to tell us if the input image is a real or fake image/data (binary /single class classification problem). So this output layer will produce only a value. The sigmoid activation function is used to convert the output value into a probability score (between 0 and 1).
    model.summary() # print the summary of the discriminator network

    img = Input(shape=img_shape) # The input layer of the discriminator network (the 1st layer of the discriminator network). The input layer accepts an input that has dimension of img_shape.
    validity = model(img) # The variable validity stores the probability score regarding if the input image is a real or fake data, produced by the discriminator network. model(x) means use the defined model (generator network) to produce the output, by taking x as the input.

    return Model(img, validity)  # Grouping the layers defined for the discriminator network into an object with training/inference features, by specifing the variable img as its input and the variable validity as its output.

# The validity is the Discriminator’s guess of input being real or not (in the form of probability score).

# %% [markdown]
# # Define the function to perform the GAN model training
#
# 1) **GAN Model training procedure:**
#     1) Set the humber of epochs for training, the batch size (the number of images involved in the training at each epoch), the epoch interval to save the images generated by the generator network (the saved images are generated for visualization purpose only, not involved in the training)
#     2) For each  epoch:
#         1) Part 1: Train Discriminator (Use the discriminator network only)
#             1) Use the real and fake (generated) images separately to train the discriminator network to only recognize real images as real images (not fooled by the fake images). At each epoch, we randomly select half batch numbers of the real images from the dataset & generate half batch numbers of random noise/latent vector, before the discriminator network training is started.
#             2) The discriminator network accepts real and fake (generated) images as the input, and
#             3) provides the probability scores of the given images being the real images as the output
#             4) Calculate the cost function value (the total loss of each epoch), then use the cost function value to learn (update) the parameters (weights and biases) of the discriminator network only that allows the discriminator network to only recognize real images as real images (not fooled by the fake images)
#         2) Part 2: Train Generator (Use the GAN model [generator network + discriminator network])
#             1) Use the real and fake (generated) images separately to train the discriminator network to only recognize real images as real images (not fooled by the fake images)
#             2) The GAN model accepts a batch (group) of randomly generated noise vectors as the input (actually it is the generator network accepts the randomly generated noise vectors as the input)
#             3) The generator network generates a batch of images (fake images) as its output (For each noise vector, the generator network generates 1 image (fake image))
#             4) The discriminator network then accepts that batch of images (fake images) generated by the generator network as its input. At the same time, the discriminator network is set to not trainable (so the weights and biases of the discriminator network will not be affected by the cost function value of this epoch at this stage)
#             5) The discriminator network then provides the probability scores of the given images being the real images as the output (as the output of the GAN model)
#             6) Calculate the cost function value (the total loss of each epoch), then use the cost function value to learn (update) the parameters (weights and biases) of the generator network only. So when more and more epochs are conducted, the generator network becomes more capable to generate fake images that are similar to the real images recognized by the discriminator network [at least causing the discriminator network to recognize the fake images as real images at high probability]
#
#
# 2) **VERY IMPORTANT UNDERSTANDING OF GAN TRAINING CONCEPT:**
#     1) At each epoch of training (especially at the 1st epoch), the key is to train the discriminator network to recognize real images using the real images first.
#     2) After the discriminator network is completely trained to recognize real images using the real images, the discriminator network is trained to recognize the real images using the fake images. This is because after the discriminator network has been trained to recognize the real images using the real images to some extent (at this moment, the discriminator network knows nothing exists in its world except the real images, and its learned weights and biases can tell if a given image is a real image (at this stage, when the discriminator network is provided with real images, it provides the probability scores of the given images being the real images > 0.5)), when the discriminator network is trained to recognize the real images with the fake images, the discriminator network can tell the given fake images are not real images (provide the probability scores of the given images being the real images < 0.5).
#     3) Since we assume the ground truth of a real image is a value of 1, when the discriminator network is firstly trained to recognize the real images with real images (remember that the definition of neural network training is to update the neural network's weights so that the training loss reduces), the discriminator network will provide the probability score of the given image being a real image > 0.5. So now when we want to keep training the discriminator network to recognize the real images, we can train the discriminator network to recognize the real images by using the fake images and assume the ground truth of a fake image (adversarial to real image) is a value of 0 (adversarial to 1).
#     4) Since before this the discriminator network already trained to recognize the real images using the real images to some extent, when it is given with the fake images in the training, its learned weights and biases will produce probability score of the given image being a real image < 0.5 (adversarial to > 0.5).
#     5) Since the learning of a neural network is related to the gradient descent (which is also related to the partial derivative of the cost function with respect to each weight and bias), the cost function must be kept as small as possible (no matter the discriminator network is trained to recognize real images with real images or fake images) so that the discriminator network training will keep proceed in the same direction (to recognize real images better and better).
#     6) Hence:
#         1) The ground truth of a real image is assumed as a value of 1 + the probabilty score provided by the discriminator network for a real image is closer to 1 makes the cost function value tends to be smaller in the training with real images;
#         2) The ground truth of a fake image is assumed as a value of 0 + the probabilty score provided by the discriminator network for a fake image is closer to 0 makes the cost function value tends to be smaller in the training with fake images.
#     7) And that's why the discriminator network is trained in the same direction (to recognize the real images better and better) when its trainings are involving real images and fake images separately.
#     8) Since now the discriminator network has been trained with the ability to tell a given fake image is not a real image (can differentiate), the generator network can proceed with its training (to learn the ability to generate fake images that are similar to the real images recognized by the discriminator network) by generating fake images and see if the discriminator network will be fooled (recognize the fake images as the real images).
#     9) Since in the generator network training, the ground truth takes the ground truth of real image (value of 1). So at each epoch, the many the generated (fake) images can fool the discriminator network, the many times the discriminator network will provide probability score closer to 1 in that epoch, and causing the cost function value of that epoch tends to become smaller.
#     10) Remember that (the definition of neural network training is to update the neural network's weights so that the training loss reduces) + (the discriminator network will provide the probability score of the given image being a real image > 0.5 [even if it is fooled by a fake image] and causes the cost function value to tend to be smaller), so actually the generator network is also trained in the same direction as the discriminator network (to learn the ability [weights and biases] to generate fake images that are similar to the real images recognized by the discriminator network [at least causing the discriminator network to recognize the fake images as real images at high probability]).
#     11) In summary, the discriminator network can be treated as a level/challenge for the generator network. If we want to train a generator network to able to generate very realistic images (the data we want) well, we must first train the discriminator network to able to recognize the realistic images (the data we want) well.

# %%
# Now that we have constructed our two models (generator network and discriminator network), it’s time to pit them against each other.
# We do this by defining a training function, loading the dataset, rescaling the dataset (our training images) and setting the ground truths. 
def train(epochs, batch_size=128, save_interval=50): # epochs refers to the training epochs, batch_size refers to the number of images/samples we used to train the GAN in each, save_interval means we save generated image samples at every save_interval numbers of epoch 

    # Load the dataset (real images/data)
    (X_train, _), (_, _) = mnist.load_data() # We only get the train set of the dataset

    # Convert each feature (pixel value) of each image into a float number and Rescale it into the range from -1 to 1 [by dividing with 255/2=127.5, where 255 is the maximum pixel value] (Can also rescale it into the range from 0 to 1 [by dividing with 255, where 255 is the maximum pixel value])
    X_train = (X_train.astype(np.float32) - 127.5) / 127.5

# Add a new dimension to the variable X_train as the channel dimension (because the size of the variable X_train is (6000,28,28) [6000 images, each image has dimension of 28 x 28 pixels, without having a dimension for color channel] but the output of the generator network and input of the discriminator network have size of (28,28,1), this means the variable X_train lack a dimension for the channel, so we manually add that dimension to the variable X_train)
    X_train = np.expand_dims(X_train, axis=3) 

    half_batch = int(batch_size / 2) # half of the batch containing the real images & reserve another half of the batch to store the fake data (images generated by the generator network) for training

# We then loop through a number of epochs to train the discriminator network by first selecting a random batch of images from our true dataset, generating a set of images from our
#Generator, feeding both set of images into our Discriminator, and finally setting the
#loss parameters for both the real and fake images, as well as the combined loss. 
    
    for epoch in range(epochs):

        # ---------------------
        #  Part 1) Train Discriminator (Use the discriminator network only)
        #  a) Use the real and fake (generated) images separately to train the discriminator network to only recognize real images as real images (not fooled by the fake images)
        #  b) The discriminator network accepts real and fake (generated) images as the input, and
        #  c) provides the probability scores of the given images being the real images as the output
        #  d) Calculate the cost function value (the total loss of each epoch), then use the cost function value to learn (update) the parameters (weights and biases) of the discriminator network only that allows the discriminator network to only recognize real images as real images (not fooled by the fake images)
        # ---------------------

        # Select a random half batch of real images, by randomly generating half_batch (size) numbers of integers between the range from 0 (low) to X_train.shape[0] (high). Each randomly generated interger by the function represents the index of the image/sample in the variable X_train. The randomly generated indices for the real images (images in the variable X_train) are stored in the variable idx. Since each integer is randomly generated between the given range, it is possible to have multiple same integer (index of an image/sample) in idx, so that it is possible to use multiple same real images for training.
        idx = np.random.randint(0, X_train.shape[0], half_batch) # Syntax -> p.random.randint(low, high, size)
        imgs = X_train[idx] # Load the features of the real images, whose indices are available in the variable idx, into the variable imgs. In other words, the variable imgs stores the features of the real images that will be used for training.

        # Generate half_batch number of noise vector (samples) [this means the variable noise contains half_batch numbers of noise vector], each noise vector has 100 features/elements. Each feature/element is a random number drawned from a normal distribution with centre(mu) and scale(sigma).
        noise = np.random.normal(0, 1, (half_batch, 100)) # Syntax -> np.random.normal(mu, sigma, size )

        # Generate a half batch of fake images. This is done by providing the noise vectors to the generator network called generator to predict (generate) images [fake images] (Each noise vector (sample) in the variable noise is also called as noise seed [here, the variable noise has half_batch numbers of noise seeds (samples/rows)], each noise seed having 100 features/elements. The generator network predict (generate) 1 image [fake image] for each noise seed)
        gen_imgs = generator.predict(noise)

        # Train the discriminator on real and fake images, separately
        # Research showed that separate training is more effective. 
        d_loss_real = discriminator.train_on_batch(imgs, np.ones((half_batch, 1)))
            # Information of train_on_batch():
            #   1) According to Keras documentation, train_on_batch() runs a single gradient update on a single batch of data, then returns a scalar loss value. This means train_on_batch() runs the model training using the features and target (ground truth) of a batch of samples (images), followed by automatically calculating the loss of the training, then update the weights of the model, and finally return the calculated training loss in one-shot.
            #   2) According to StackExchange, train_on_batch() allows you to expressly update the weights of your model based on a collection of samples you provide, without regard to any fixed batch size. You could use train_on_batch() to directly update the weights of the existing model only on those samples you provide. Reference: https://stackoverflow.com/questions/49100556/what-is-the-use-of-train-on-batch-in-keras
            # np.ones((half_batch, 1)) creates a 1D vector storing the label (ground truth) of each real image. The label (ground truth) of a real image is a value of 1. This means np.ones((half_batch, 1)) creates a 1D vector that has half_batch rows of value 1. 
            # For each real image, train_on_batch() uses the discriminator network called discriminator to generate a probability score of that image as a real image, then use the generated probability score and the ground truth (value of 1) to calculate the loss.
            # Hence, the variable d_loss_real stores the loss of each real image (this means d_loss_real has size of (half_batch, 1))
            # ** VERY IMPORTANT UNDERSTANDING OF GAN TRAINING CONCEPT:**
            # --> At each epoch of training (especially at the 1st epoch), the key is to train the discriminator network to recognize real images first. After the discriminator network is completely trained to recognize real images, the discriminator network is trained to recognize the fake images. This is because after the discriminator network has been trained to recognize the real images to some extent (at this moment, the discriminator network knows nothing exists in its world except the real images, and its learned weights and biases can tell if a given image is a real image (at this stage, when the discriminator network is provided with real images, it provides the probability scores of the given images being the real images > 0.5)), when the discriminator network is trained with the fake images, the discriminator network can tell the given fake images are not real images (provide the probability scores of the given images being the real images < 0.5). Since we assume the ground truth of a real image is a value of 1, when the discriminator network is firstly trained with real images (remember that the definition of neural network training is to update the neural network's weights so that the training loss reduces), the discriminator network will provide the probability score of the given image being a real image > 0.5. So now when we want to keep training the discriminator network to recognize the real images, we can train the discriminator network by using the fake images and assume the ground truth of a fake image (adversarial to real image) is a value of 0 (adversarial to 1). Since before this the discriminator network already trained to recognize the real images to some extent, when it is given with the fake images in the training, its learned weights and biases will produce probability score of the given image being a real image < 0.5 (adversarial to > 0.5). Since the learning of a neural network is related to the gradient descent (which also related to the derivative of the cost function with respect to each weight and bias), the cost function must be kept as small as possible (no matter the discriminator network is trained to recognize real images with real images or fake images) so that the discriminator network training will keep proceed in the same direction (to recognize real images better and better). Hence, the ground truth of a real image is assumed as a value of 1 + the probabilty score provided by the discriminator network for a real image is closer to 1 makes the cost function value tends to be smaller in the training with real images; the ground truth of a fake image is assumed as a value of 0 + the probabilty score provided by the discriminator network for a fake image is closer to 0 makes the cost function value tends to be smaller in the training with fake images. And that's why the discriminator network is trained in the same direction (to recognize the real images better and better) when its trainings are involving real images and fake images separately. Since now the discriminator network has been trained with the ability to tell a given fake image is not a real image (can differentiate), the generator network can proceed with its training (to learn the ability to generate fake images that similar to the real images) by generating fake images and see if the discriminator network will be fooled (recognize a fake image as a real image). Since in the generator network training, the ground truth takes the ground truth of real image (value of 1). So at each epoch, the many the generated (fake) images can fool the discriminator network, the many times the discriminator network will provide probability score of 1 in that epoch, and the cost function value of that epoch tends to become smaller. Remember that (the definition of neural network training is to update the neural network's weights so that the training loss reduces) + (the discriminator network will provide the probability score of the given image being a real image > 0.5 [even if it is fooled by a fake image] and causes the cost function value to tend to be smaller), so actually the generator network is also trained in the same direction as the discriminator network (to learn the ability [weights and biases] to generate fake images that are similar to the real images recognized by the discriminator network [at least causing the discriminator network to recognize the fake images as real images at high probability]). In summary, the discriminator network can be treated as a level/challenge for the generator network. If we want to train a generator network to able to generate very realistic images (the data we want) well, we must first train the discriminator network to able to recognize the realistic images (the data we want) well.
            
        d_loss_fake = discriminator.train_on_batch(gen_imgs, np.zeros((half_batch, 1)))
            # np.zeros((half_batch, 1)) creates a 1D vector storing the label (ground truth) of each fake image. The label (ground truth) of a fake image is a value of 0. This means np.zeros((half_batch, 1)) creates a 1D vector that has half_batch rows of value 0. 
            # For each fake image, train_on_batch() uses the discriminator network called discriminator to generate a probability score of that image as a fake image, then use the generated probability score and the ground truth (value of 0) to calculate the loss.
            # Hence, the variable d_loss_fake stores the loss of each fake image (this means d_loss_fake has size of (half_batch, 1))

        # Take average loss from real and fake images and store it in the variable d_loss. This means the variable d_loss stores a value that represents the loss of the discriminator training in this epoch.
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake) 

# And within the same loop we train our Generator, by setting the input noise and
# ultimately training the Generator to have the Discriminator label its samples as valid
# by specifying the gradient loss.
        # ---------------------
        #  Part 2: Train Generator (Use the GAN model [generator network + discriminator network])
        #  a) Use the real and fake (generated) images separately to train the discriminator network to only recognize real images as real images (not fooled by the fake images)
        #  b) The GAN model accepts a batch (group) of randomly generated noise vectors as the input (actually it is the generator network accepts the randomly generated noise vectors as the input)
        #  c) The generator network generates a batch of images (fake images) as its output (For each noise vector, the generator network generates 1 image (fake image))
        #  d) The discriminator network then accepts that batch of images (fake images) generated by the generator network as its input. At the same time, the discriminator network is set to not trainable (so the weights and biases of the discriminator network will not be affected by the cost function value of this epoch at this stage)
        #  e) The discriminator network then provides the probability scores of the given images being the real images as the output (as the output of the GAN model)
        #  f) Calculate the cost function value (the total loss of each epoch), then use the cost function value to learn (update) the parameters (weights and biases) of the generator network only. So when more and more epochs are conducted, the generator network becomes more capable to generate fake images that are similar to the real images recognized by the discriminator network [at least causing the discriminator network to recognize the fake images as real images at high probability]
        # ---------------------

# Create noise vectors as input for generator. 
# Create as many noise vectors as defined by the batch size. 
# Based on normal distribution. Output will be of size (batch size, 100)
        noise = np.random.normal(0, 1, (batch_size, 100)) # This means here randomly generate half_batch number of noise vector (samples) again.

        # The generator wants the discriminator to label the generated samples
        # as valid/real (ones)
        # This is where the generator is trying to trick discriminator into believing
        # the generated image is true/real/valid (hence value of 1 for y)
        valid_y = np.array([1] * batch_size) # Creates an array of all 1 of size=batch size (means creates a column of value=ground truth of a real image), to trick the discriminator to believe each generated/fake image is a real image

        # Generator is part of combined where it got directly linked with the discriminator
        # Train the generator with noise as x and 1 as y. 
        # Again, 1 as the output as it is adversarial and if generator did a great
        # job of folling the discriminator then the output would be 1 (true)
        g_loss = combined.train_on_batch(noise, valid_y) # since we used the model called combined to get the g_loss, only the parameters (weights and biases) of the generator network will be updated (learned) with the cost function value of each epoch (the discriminator network is set as not trainable in the combined model)
            # Similar to the concept of training an autoencoder, we need to pass the input data to the autoencoder (encoder + decoder) in order to train its encoder network (the decoder provides its output by taking the encoder's output as its input, then use the decoder's output and the ground truth of the sample to calculate the loss for that sample. Then the calculated loss will be used to update the weights and biases of the encoder and decoder networks)
            # Analogously, we need to pass the input data to the GAN (generator + discriminator) in order to train its generator network (the discriminator network provides its output (probability score of the image as a real image) by taking the generator network's output (generated image) as its input, then use the discriminator's output (probability score of the image as a real image) and the ground truth of a real image (to trick the discriminator network to believe that generated image is a real image) to calculate the loss for that generated image. Then the calculated loss will be used to update the weights and biases of the generator network only)).
            # Hence, in an training epoch [after comnpletely passing batch_size numbers of images into the network represents 1 epoch completed], if the discriminator network:
            # 1) knows the generated image is not a real image (probability score < 0.5), then the loss of that sample is larger, causing the total loss of that training epoch to increase, causing the weights and biases of the generator network to update (learn) more. 
            # 2) don't knows the generated image is not a real image [means the discriminator is tricked to believe that generated image is a real image] (probability score >= 0.5), then the loss of that sample is smaller, causing the total loss of that training epoch to decrease, causing the weights and biases of the generator network to update (learn) less. 

# Additionally, in order for us to keep track of our training process, we print the
# progress and save the sample image output depending on the epoch interval specified.  

        # Plot the progress
        print ("Epoch %d: [Discriminator loss= %f, Discriminator accuracy= %.2f%%] [Generator loss= %f]" % (epoch, d_loss[0], 100*d_loss[1], g_loss))

        # If at save interval => save generated image samples
        if epoch % save_interval == 0:
            save_imgs(epoch)

# %% [markdown]
# # Define the function to save the images generated by the generator network at every epoch interval
# The images (fake images) generated are for visualization purpose (for user to see the ability of the generator network in generating images) only. They are not involved in the training (updating the weights and biases of both generator and discriminator networks)

# %%
# when the specific sample_interval is hit, we call the sample_image function. Which looks as follows. 
# Summary, this save_imgs() will ask the generator network of the GAN to generate 25 images (fake images). Each fake image is generated based on a randomly generated noise vector. Hence, at a particular epoch, we can get a sense of how good are the parameters (weights and biases) of the generator network updated, by visualizing the 25 images the generator networks generated at that epoch.

def save_imgs(epoch):
    r, c = 5, 5
    noise = np.random.normal(0, 1, (r * c, 100)) # This means here randomly generate half_batch number of noise vector (samples) again.
    gen_imgs = generator.predict(noise) # With the latest updated/learned parameters (weights and biases), the generator network generates 1 image (fake image) for each randomly created noise vector stored in the variable noise. So eventually the generator network will generate 25 images.

    # Rescale images 0 - 1
    gen_imgs = 0.5 * gen_imgs + 0.5

    # Create the directory (folder) if the directory is not exist. If the directory exists, just skip it (nothing happens).
    os.makedirs('D:/AI_Master_New/Under_Local_Git_Covered/Deep_Learning_Tutorials_codebasics/Generative_Adversarial_Network_GAN/GAN_DigitalSreeni/images', exist_ok = True)

    # Create a 5x5 subplot that shows 25 images in one-shot
    fig, axs = plt.subplots(r, c)
    cnt = 0
    for i in range(r):
        for j in range(c):
            axs[i,j].imshow(gen_imgs[cnt, :,:,0], cmap='gray')
            axs[i,j].axis('off')
            cnt += 1
    time_now  = datetime.datetime.now().strftime('%Y_%m_%d_%H_%M_%S') # Get the current date and time right before saving the created 5x5 subplot
    fig.savefig('images/%s_mnist_Epoch%d.png' % (time_now, epoch)) # Save the created 5x5 subplot at the directory
    plt.close()
#This function saves our images for us to view

# %% [markdown]
# # Develop the GAN, by combining the generator network and discriminator network as one
#
# 1) This is the main function block of this script
# 2) Here, we have 4 parts:
#     1) Part 1: Discriminator network
#         1) Build the discriminator network (call build_discriminator() to group the defined layers into an object with training/inference features)
#         2) Compile the discriminator network (This finalizes the model, freezes all its settings, and prepares it to meet some data)
#     2) Part 2: Generator network
#         1) Build the generator network (call build_generator() to group the defined layers into an object with training/inference features)
#         2) Compile the generator network (This finalizes the model, freezes all its settings, and prepares it to meet some data)
#     3) Part 3: GAN model
#         1) Define the structure of the GAN model. GAN model only has 4 layers:
#             1) Layer 1: The input layer (the variable z)
#             2) Layer 2: The generator network
#             3) Layer 3: The discriminator network
#             4) Layer 4: The output layer (the variable valid)
#         2) Build the GAN model (call Model() to group the defined layers into an object with training/inference features)
#         3) Compile the GAN model (This finalizes the model, freezes all its settings, and prepares it to meet some data)
#     4) Part 4: Perform GAN model training
#     5) Part 5: After the GAN model traning is completed, save the trained generator network of the GAN model

# %%
########################Main function block of this script##########################################

# Let us also define our optimizer for easy use later on. That way if you change your mind, you can change it easily here
optimizer = adam_v2.Adam(0.0002, 0.5)  #Learning rate and momentum.

#**********************Before combining the generator and discriminator networks**********************
#-------------------------Discriminator Network Part-------------------------
# Build and compile the discriminator first:
# Extra information:
#   1) Generator will be trained as part of the combined model, later. 
#   2) Pick the loss function and the type of metric to keep track.                 
#   3) We choose the binary cross entropy as the cost function because we are doing prediction on binary problem (O-> fake image or 1-> real image) and it is a better
#   loss function compared to MSE or other for our tasks. 

# Build a build_discriminator object called discriminator (the discriminator network), using the network structure defined in the build_discriminator().
discriminator = build_discriminator() 
# Compile the discriminator network
discriminator.compile(loss='binary_crossentropy',
    optimizer=optimizer,
    metrics=['accuracy'])

#-------------------------Generator Network Part-------------------------
# Build and compile our generator, pick the loss function:
# Extra information:
#   1) Since we are only generating (faking) images, let us not track any metrics.

# Build a build_generator object called generator (the generator network), using the network structure defined in the build_generator().
generator = build_generator() 
# Compile the generator network
generator.compile(loss='binary_crossentropy', optimizer=optimizer)


#**********************Combining the generator and discriminator networks as a GAN model**********************
#-------------------------GAN model Part-------------------------
# In a GAN, the Generator network takes noise z as an input to produce its images.  
z = Input(shape=(100,))   # The input layer of the GAN model. Define the variable z is the input to the GAN (also means the variable z is the input to the generator network in the GAN)
img = generator(z) # call generator() to use generator network to generate 1 image (fake image) per noise vector in the variable z

# This ensures that when we combine our generator and discriminator networks, we only train the Generator.
# While generator training we do not want discriminator weights to be adjusted. 
# This Doesn't affect the above descriminator training.     
discriminator.trainable = False  

# This specifies that our Discriminator will take the images generated by our Generator
# and true dataset and set its output to a parameter called valid, which will indicate
# whether the input is real (real image) or not (fake image).  
valid = discriminator(img)  # The output layer of the GAN model. Call discriminator() to use discriminator network to perform validity check on all the generated images stored in the variable img


# Here we combined the generator and discriminator models as a GAN model, and also set our loss function and optimizer for the GAN model. 
# Again, we are only training the generator here. 
# The ultimate goal here is for the Generator to fool the Discriminator.  
# The combined model, also known as GAN model  (stacked generator and discriminator) takes
# noise as input => generates images => determines validity

# Build a GAN model called combined. This GAN model accepts the variable z as the input, then provides the variable valid as the output.
combined = Model(z, valid)
# Compile the GAN model
combined.compile(loss='binary_crossentropy', optimizer=optimizer)


#**********************Perform GAN model training**********************
# Perform GAN model training, with epochs numbers of epochs. At each epoch, batch_size numbers of images are used. At every epoch interval of save_interval, use the generator network to generate extra 25 images (fake images) (based on the randomly generated noise vectors, 1 image per noise vector) with the latest weigths and biases at that time (for visualization purpose only, not involved in the training), followed by making the 25 generated images into a subplot then save to the local device.
train(epochs=5001, batch_size=32, save_interval=500)


#**********************Save the trained generator network**********************
#Save model for future use to generate fake images
#Not tested yet... make sure right model is being saved..
#Compare with GAN4

# Save the trained generator network (means save the weights and biases of the generator network as a file, so that we can directly use the generator network in other applications)
generator.save('generator_model.h5')  


#Test the model on GAN4_predict...
#Change epochs back to 30K
                
#Epochs dictate the number of backward and forward propagations, the batch_size
#indicates the number of training samples per backward/forward propagation, and the
#sample_interval specifies after how many epochs we call our sample_image function.
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               401920
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               131328
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 533,505
# Trainable params: 533,505
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 256)               25856
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 256)               0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_11 (Dense)             (None, 512)               131584
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 512)               0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 512)               2048
# _________________________________________________________________
# dense_12 (Dense)             (None, 1024)              525312
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 1024)              0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 1024)              4096
# _________________________________________________________________
# dense_13 (Dense)             (None, 784)               803600
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 28, 28, 1)         0
# =================================================================
# Total params: 1,493,520
# Trainable params: 1,489,936
# Non-trainable params: 3,584
# _________________________________________________________________
# Epoch 0: [Discriminator loss= 0.518203, Discriminator accuracy= 71.88%] [Generator loss= 0.660638]
# Epoch 1: [Discriminator loss= 0.341460, Discriminator accuracy= 90.62%] [Generator loss= 0.638008]
# Epoch 2: [Discriminator loss= 0.320930, Discriminator accuracy= 90.62%] [Generator loss= 0.696392]
# Epoch 3: [Discriminator loss= 0.321515, Discriminator accuracy= 90.62%] [Generator loss= 0.860583]
# Epoch 4: [Discriminator loss= 0.317891, Discriminator accuracy= 87.50%] [Generator loss= 0.984748]
# Epoch 5: [Discriminator loss= 0.307332, Discriminator accuracy= 84.38%] [Generator loss= 1.095828]
# Epoch 6: [Discriminator loss= 0.241045, Discriminator accuracy= 100.00%] [Generator loss= 1.348621]
# Epoch 7: [Discriminator loss= 0.184504, Discriminator accuracy= 96.88%] [Generator loss= 1.495807]
# Epoch 8: [Discriminator loss= 0.164466, Discriminator accuracy= 100.00%] [Generator loss= 1.712672]
# Epoch 9: [Discriminator loss= 0.123237, Discriminator accuracy= 100.00%] [Generator loss= 1.730039]
# Epoch 10: [Discriminator loss= 0.105707, Discriminator accuracy= 100.00%] [Generator loss= 1.912397]
# Epoch 11: [Discriminator loss= 0.100156, Discriminator accuracy= 100.00%] [Generator loss= 2.125353]
# Epoch 12: [Discriminator loss= 0.084077, Discriminator accuracy= 100.00%] [Generator loss= 2.286123]
# Epoch 13: [Discriminator loss= 0.075069, Discriminator accuracy= 100.00%] [Generator loss= 2.373146]
# Epoch 14: [Discriminator loss= 0.068024, Discriminator accuracy= 100.00%] [Generator loss= 2.438786]
# Epoch 15: [Discriminator loss= 0.058855, Discriminator accuracy= 100.00%] [Generator loss= 2.602440]
# Epoch 16: [Discriminator loss= 0.063389, Discriminator accuracy= 100.00%] [Generator loss= 2.748954]
# Epoch 17: [Discriminator loss= 0.040486, Discriminator accuracy= 100.00%] [Generator loss= 2.867908]
# Epoch 18: [Discriminator loss= 0.040214, Discriminator accuracy= 100.00%] [Generator loss= 2.897777]
# Epoch 19: [Discriminator loss= 0.039139, Discriminator accuracy= 100.00%] [Generator loss= 2.985726]
# Epoch 20: [Discriminator loss= 0.037432, Discriminator accuracy= 100.00%] [Generator loss= 3.098916]
# Epoch 21: [Discriminator loss= 0.035483, Discriminator accuracy= 100.00%] [Generator loss= 3.167599]
# Epoch 22: [Discriminator loss= 0.055952, Discriminator accuracy= 100.00%] [Generator loss= 3.079131]
# Epoch 23: [Discriminator loss= 0.024064, Discriminator accuracy= 100.00%] [Generator loss= 3.193169]
# Epoch 24: [Discriminator loss= 0.025448, Discriminator accuracy= 100.00%] [Generator loss= 3.128970]
# Epoch 25: [Discriminator loss= 0.029757, Discriminator accuracy= 100.00%] [Generator loss= 3.348680]
# Epoch 26: [Discriminator loss= 0.035952, Discriminator accuracy= 100.00%] [Generator loss= 3.418533]
# Epoch 27: [Discriminator loss= 0.016371, Discriminator accuracy= 100.00%] [Generator loss= 3.417823]
# Epoch 28: [Discriminator loss= 0.016662, Discriminator accuracy= 100.00%] [Generator loss= 3.372663]
# Epoch 29: [Discriminator loss= 0.019772, Discriminator accuracy= 100.00%] [Generator loss= 3.488123]
# Epoch 30: [Discriminator loss= 0.025101, Discriminator accuracy= 100.00%] [Generator loss= 3.554920]
# Epoch 31: [Discriminator loss= 0.019676, Discriminator accuracy= 100.00%] [Generator loss= 3.571959]
# Epoch 32: [Discriminator loss= 0.017740, Discriminator accuracy= 100.00%] [Generator loss= 3.593023]
# Epoch 33: [Discriminator loss= 0.016373, Discriminator accuracy= 100.00%] [Generator loss= 3.598184]
# Epoch 34: [Discriminator loss= 0.018503, Discriminator accuracy= 100.00%] [Generator loss= 3.650278]
# Epoch 35: [Discriminator loss= 0.015961, Discriminator accuracy= 100.00%] [Generator loss= 3.750497]
# Epoch 36: [Discriminator loss= 0.016847, Discriminator accuracy= 100.00%] [Generator loss= 3.815278]
# Epoch 37: [Discriminator loss= 0.021243, Discriminator accuracy= 100.00%] [Generator loss= 3.692507]
# Epoch 38: [Discriminator loss= 0.013933, Discriminator accuracy= 100.00%] [Generator loss= 3.811460]
# Epoch 39: [Discriminator loss= 0.010065, Discriminator accuracy= 100.00%] [Generator loss= 3.756786]
# Epoch 40: [Discriminator loss= 0.016389, Discriminator accuracy= 100.00%] [Generator loss= 3.938268]
# Epoch 41: [Discriminator loss= 0.012990, Discriminator accuracy= 100.00%] [Generator loss= 3.777673]
# Epoch 42: [Discriminator loss= 0.017891, Discriminator accuracy= 100.00%] [Generator loss= 3.752045]
# Epoch 43: [Discriminator loss= 0.013621, Discriminator accuracy= 100.00%] [Generator loss= 3.875534]
# Epoch 44: [Discriminator loss= 0.011684, Discriminator accuracy= 100.00%] [Generator loss= 3.869633]
# Epoch 45: [Discriminator loss= 0.012564, Discriminator accuracy= 100.00%] [Generator loss= 3.888414]
# Epoch 46: [Discriminator loss= 0.015012, Discriminator accuracy= 100.00%] [Generator loss= 3.907980]
# Epoch 47: [Discriminator loss= 0.019440, Discriminator accuracy= 100.00%] [Generator loss= 4.074389]
# Epoch 48: [Discriminator loss= 0.021121, Discriminator accuracy= 100.00%] [Generator loss= 4.028478]
# Epoch 49: [Discriminator loss= 0.021100, Discriminator accuracy= 100.00%] [Generator loss= 4.209277]
# Epoch 50: [Discriminator loss= 0.014808, Discriminator accuracy= 100.00%] [Generator loss= 4.169506]
# Epoch 51: [Discriminator loss= 0.007984, Discriminator accuracy= 100.00%] [Generator loss= 4.197398]
# Epoch 52: [Discriminator loss= 0.013086, Discriminator accuracy= 100.00%] [Generator loss= 4.287404]
# Epoch 53: [Discriminator loss= 0.006025, Discriminator accuracy= 100.00%] [Generator loss= 4.282148]
# Epoch 54: [Discriminator loss= 0.010351, Discriminator accuracy= 100.00%] [Generator loss= 4.113537]
# Epoch 55: [Discriminator loss= 0.010401, Discriminator accuracy= 100.00%] [Generator loss= 4.045036]
# Epoch 56: [Discriminator loss= 0.010521, Discriminator accuracy= 100.00%] [Generator loss= 4.010155]
# Epoch 57: [Discriminator loss= 0.011491, Discriminator accuracy= 100.00%] [Generator loss= 4.150762]
# Epoch 58: [Discriminator loss= 0.011768, Discriminator accuracy= 100.00%] [Generator loss= 4.237828]
# Epoch 59: [Discriminator loss= 0.013025, Discriminator accuracy= 100.00%] [Generator loss= 4.151574]
# Epoch 60: [Discriminator loss= 0.011454, Discriminator accuracy= 100.00%] [Generator loss= 4.303259]
# Epoch 61: [Discriminator loss= 0.006697, Discriminator accuracy= 100.00%] [Generator loss= 4.408922]
# Epoch 62: [Discriminator loss= 0.010687, Discriminator accuracy= 100.00%] [Generator loss= 4.247423]
# Epoch 63: [Discriminator loss= 0.017101, Discriminator accuracy= 100.00%] [Generator loss= 4.318913]
# Epoch 64: [Discriminator loss= 0.008035, Discriminator accuracy= 100.00%] [Generator loss= 4.197365]
# Epoch 65: [Discriminator loss= 0.008474, Discriminator accuracy= 100.00%] [Generator loss= 4.230645]
# Epoch 66: [Discriminator loss= 0.011415, Discriminator accuracy= 100.00%] [Generator loss= 4.390787]
# Epoch 67: [Discriminator loss= 0.011615, Discriminator accuracy= 100.00%] [Generator loss= 4.168213]
# Epoch 68: [Discriminator loss= 0.012028, Discriminator accuracy= 100.00%] [Generator loss= 4.348228]
# Epoch 69: [Discriminator loss= 0.009927, Discriminator accuracy= 100.00%] [Generator loss= 4.353344]
# Epoch 70: [Discriminator loss= 0.007996, Discriminator accuracy= 100.00%] [Generator loss= 4.407847]
# Epoch 71: [Discriminator loss= 0.005740, Discriminator accuracy= 100.00%] [Generator loss= 4.287369]
# Epoch 72: [Discriminator loss= 0.008141, Discriminator accuracy= 100.00%] [Generator loss= 4.322981]
# Epoch 73: [Discriminator loss= 0.006128, Discriminator accuracy= 100.00%] [Generator loss= 4.086973]
# Epoch 74: [Discriminator loss= 0.006516, Discriminator accuracy= 100.00%] [Generator loss= 4.152693]
# Epoch 75: [Discriminator loss= 0.010139, Discriminator accuracy= 100.00%] [Generator loss= 4.115636]
# Epoch 76: [Discriminator loss= 0.015181, Discriminator accuracy= 100.00%] [Generator loss= 4.328708]
# Epoch 77: [Discriminator loss= 0.015922, Discriminator accuracy= 100.00%] [Generator loss= 4.374255]
# Epoch 78: [Discriminator loss= 0.013281, Discriminator accuracy= 100.00%] [Generator loss= 4.388135]
# Epoch 79: [Discriminator loss= 0.014033, Discriminator accuracy= 100.00%] [Generator loss= 4.409062]
# Epoch 80: [Discriminator loss= 0.016264, Discriminator accuracy= 100.00%] [Generator loss= 4.702754]
# Epoch 81: [Discriminator loss= 0.007186, Discriminator accuracy= 100.00%] [Generator loss= 4.735662]
# Epoch 82: [Discriminator loss= 0.009311, Discriminator accuracy= 100.00%] [Generator loss= 4.569322]
# Epoch 83: [Discriminator loss= 0.013465, Discriminator accuracy= 100.00%] [Generator loss= 4.480734]
# Epoch 84: [Discriminator loss= 0.007820, Discriminator accuracy= 100.00%] [Generator loss= 4.561764]
# Epoch 85: [Discriminator loss= 0.016397, Discriminator accuracy= 100.00%] [Generator loss= 4.547173]
# Epoch 86: [Discriminator loss= 0.009004, Discriminator accuracy= 100.00%] [Generator loss= 4.753860]
# Epoch 87: [Discriminator loss= 0.019115, Discriminator accuracy= 100.00%] [Generator loss= 4.738464]
# Epoch 88: [Discriminator loss= 0.009567, Discriminator accuracy= 100.00%] [Generator loss= 4.941602]
# Epoch 89: [Discriminator loss= 0.008944, Discriminator accuracy= 100.00%] [Generator loss= 4.885846]
# Epoch 90: [Discriminator loss= 0.005137, Discriminator accuracy= 100.00%] [Generator loss= 4.831631]
# Epoch 91: [Discriminator loss= 0.014588, Discriminator accuracy= 100.00%] [Generator loss= 4.680635]
# Epoch 92: [Discriminator loss= 0.008371, Discriminator accuracy= 100.00%] [Generator loss= 4.847711]
# Epoch 93: [Discriminator loss= 0.005865, Discriminator accuracy= 100.00%] [Generator loss= 4.866351]
# Epoch 94: [Discriminator loss= 0.008335, Discriminator accuracy= 100.00%] [Generator loss= 4.791657]
# Epoch 95: [Discriminator loss= 0.009733, Discriminator accuracy= 100.00%] [Generator loss= 4.880500]
# Epoch 96: [Discriminator loss= 0.009522, Discriminator accuracy= 100.00%] [Generator loss= 4.659347]
# Epoch 97: [Discriminator loss= 0.013045, Discriminator accuracy= 100.00%] [Generator loss= 5.072545]
# Epoch 98: [Discriminator loss= 0.010999, Discriminator accuracy= 100.00%] [Generator loss= 4.732288]
# Epoch 99: [Discriminator loss= 0.007040, Discriminator accuracy= 100.00%] [Generator loss= 4.972480]
# Epoch 100: [Discriminator loss= 0.007057, Discriminator accuracy= 100.00%] [Generator loss= 4.735126]
# Epoch 101: [Discriminator loss= 0.008510, Discriminator accuracy= 100.00%] [Generator loss= 4.798088]
# Epoch 102: [Discriminator loss= 0.007856, Discriminator accuracy= 100.00%] [Generator loss= 4.921325]
# Epoch 103: [Discriminator loss= 0.009933, Discriminator accuracy= 100.00%] [Generator loss= 4.872108]
# Epoch 104: [Discriminator loss= 0.012360, Discriminator accuracy= 100.00%] [Generator loss= 5.002313]
# Epoch 105: [Discriminator loss= 0.017152, Discriminator accuracy= 100.00%] [Generator loss= 5.160941]
# Epoch 106: [Discriminator loss= 0.013589, Discriminator accuracy= 100.00%] [Generator loss= 5.158753]
# Epoch 107: [Discriminator loss= 0.009726, Discriminator accuracy= 100.00%] [Generator loss= 5.159398]
# Epoch 108: [Discriminator loss= 0.005379, Discriminator accuracy= 100.00%] [Generator loss= 5.341531]
# Epoch 109: [Discriminator loss= 0.006643, Discriminator accuracy= 100.00%] [Generator loss= 5.102488]
# Epoch 110: [Discriminator loss= 0.007934, Discriminator accuracy= 100.00%] [Generator loss= 5.118658]
# Epoch 111: [Discriminator loss= 0.005952, Discriminator accuracy= 100.00%] [Generator loss= 4.970097]
# Epoch 112: [Discriminator loss= 0.006605, Discriminator accuracy= 100.00%] [Generator loss= 4.914701]
# Epoch 113: [Discriminator loss= 0.013027, Discriminator accuracy= 100.00%] [Generator loss= 5.074323]
# Epoch 114: [Discriminator loss= 0.011941, Discriminator accuracy= 100.00%] [Generator loss= 5.122182]
# Epoch 115: [Discriminator loss= 0.008668, Discriminator accuracy= 100.00%] [Generator loss= 5.157462]
# Epoch 116: [Discriminator loss= 0.020419, Discriminator accuracy= 100.00%] [Generator loss= 5.194372]
# Epoch 117: [Discriminator loss= 0.012803, Discriminator accuracy= 100.00%] [Generator loss= 5.596205]
# Epoch 118: [Discriminator loss= 0.041917, Discriminator accuracy= 100.00%] [Generator loss= 5.122394]
# Epoch 119: [Discriminator loss= 0.005519, Discriminator accuracy= 100.00%] [Generator loss= 5.326743]
# Epoch 120: [Discriminator loss= 0.009850, Discriminator accuracy= 100.00%] [Generator loss= 5.541514]
# Epoch 121: [Discriminator loss= 0.028419, Discriminator accuracy= 100.00%] [Generator loss= 5.885019]
# Epoch 122: [Discriminator loss= 0.042187, Discriminator accuracy= 100.00%] [Generator loss= 5.308859]
# Epoch 123: [Discriminator loss= 0.002232, Discriminator accuracy= 100.00%] [Generator loss= 5.596142]
# Epoch 124: [Discriminator loss= 0.025445, Discriminator accuracy= 100.00%] [Generator loss= 5.631856]
# Epoch 125: [Discriminator loss= 0.032618, Discriminator accuracy= 100.00%] [Generator loss= 6.382960]
# Epoch 126: [Discriminator loss= 0.231557, Discriminator accuracy= 93.75%] [Generator loss= 4.264490]
# Epoch 127: [Discriminator loss= 0.035184, Discriminator accuracy= 100.00%] [Generator loss= 4.331003]
# Epoch 128: [Discriminator loss= 0.026617, Discriminator accuracy= 100.00%] [Generator loss= 5.179913]
# Epoch 129: [Discriminator loss= 0.031569, Discriminator accuracy= 100.00%] [Generator loss= 5.999898]
# Epoch 130: [Discriminator loss= 0.006609, Discriminator accuracy= 100.00%] [Generator loss= 6.233700]
# Epoch 131: [Discriminator loss= 0.092556, Discriminator accuracy= 93.75%] [Generator loss= 4.632396]
# Epoch 132: [Discriminator loss= 0.042185, Discriminator accuracy= 100.00%] [Generator loss= 5.058570]
# Epoch 133: [Discriminator loss= 0.009505, Discriminator accuracy= 100.00%] [Generator loss= 5.848072]
# Epoch 134: [Discriminator loss= 0.026562, Discriminator accuracy= 100.00%] [Generator loss= 5.080598]
# Epoch 135: [Discriminator loss= 0.009131, Discriminator accuracy= 100.00%] [Generator loss= 4.684352]
# Epoch 136: [Discriminator loss= 0.039897, Discriminator accuracy= 100.00%] [Generator loss= 4.791082]
# Epoch 137: [Discriminator loss= 0.022558, Discriminator accuracy= 100.00%] [Generator loss= 5.298207]
# Epoch 138: [Discriminator loss= 0.331990, Discriminator accuracy= 81.25%] [Generator loss= 2.809310]
# Epoch 139: [Discriminator loss= 0.107720, Discriminator accuracy= 96.88%] [Generator loss= 4.114923]
# Epoch 140: [Discriminator loss= 0.045926, Discriminator accuracy= 96.88%] [Generator loss= 5.463238]
# Epoch 141: [Discriminator loss= 0.036177, Discriminator accuracy= 100.00%] [Generator loss= 5.486855]
# Epoch 142: [Discriminator loss= 0.037835, Discriminator accuracy= 100.00%] [Generator loss= 4.462917]
# Epoch 143: [Discriminator loss= 0.033026, Discriminator accuracy= 100.00%] [Generator loss= 4.396146]
# Epoch 144: [Discriminator loss= 0.131470, Discriminator accuracy= 93.75%] [Generator loss= 5.494244]
# Epoch 145: [Discriminator loss= 0.932191, Discriminator accuracy= 68.75%] [Generator loss= 3.504926]
# Epoch 146: [Discriminator loss= 0.058254, Discriminator accuracy= 96.88%] [Generator loss= 4.739651]
# Epoch 147: [Discriminator loss= 0.088957, Discriminator accuracy= 100.00%] [Generator loss= 3.628031]
# Epoch 148: [Discriminator loss= 0.049854, Discriminator accuracy= 100.00%] [Generator loss= 4.103399]
# Epoch 149: [Discriminator loss= 0.038486, Discriminator accuracy= 100.00%] [Generator loss= 3.985581]
# Epoch 150: [Discriminator loss= 0.137054, Discriminator accuracy= 96.88%] [Generator loss= 3.999753]
# Epoch 151: [Discriminator loss= 0.058527, Discriminator accuracy= 100.00%] [Generator loss= 4.006476]
# Epoch 152: [Discriminator loss= 0.048463, Discriminator accuracy= 96.88%] [Generator loss= 3.983385]
# Epoch 153: [Discriminator loss= 0.385670, Discriminator accuracy= 84.38%] [Generator loss= 2.265945]
# Epoch 154: [Discriminator loss= 0.183825, Discriminator accuracy= 87.50%] [Generator loss= 3.388407]
# Epoch 155: [Discriminator loss= 0.032903, Discriminator accuracy= 100.00%] [Generator loss= 5.194005]
# Epoch 156: [Discriminator loss= 0.954892, Discriminator accuracy= 56.25%] [Generator loss= 1.923013]
# Epoch 157: [Discriminator loss= 0.337854, Discriminator accuracy= 78.12%] [Generator loss= 3.547888]
# Epoch 158: [Discriminator loss= 0.111817, Discriminator accuracy= 93.75%] [Generator loss= 5.656124]
# Epoch 159: [Discriminator loss= 0.910783, Discriminator accuracy= 59.38%] [Generator loss= 2.856304]
# Epoch 160: [Discriminator loss= 0.145788, Discriminator accuracy= 93.75%] [Generator loss= 3.542355]
# Epoch 161: [Discriminator loss= 0.136048, Discriminator accuracy= 93.75%] [Generator loss= 3.217153]
# Epoch 162: [Discriminator loss= 0.157012, Discriminator accuracy= 90.62%] [Generator loss= 4.122309]
# Epoch 163: [Discriminator loss= 0.379568, Discriminator accuracy= 75.00%] [Generator loss= 3.619455]
# Epoch 164: [Discriminator loss= 0.216912, Discriminator accuracy= 93.75%] [Generator loss= 4.242439]
# Epoch 165: [Discriminator loss= 0.411001, Discriminator accuracy= 81.25%] [Generator loss= 1.645521]
# Epoch 166: [Discriminator loss= 0.620298, Discriminator accuracy= 65.62%] [Generator loss= 2.875741]
# Epoch 167: [Discriminator loss= 0.059512, Discriminator accuracy= 100.00%] [Generator loss= 4.653445]
# Epoch 168: [Discriminator loss= 0.237648, Discriminator accuracy= 90.62%] [Generator loss= 2.279058]
# Epoch 169: [Discriminator loss= 0.310987, Discriminator accuracy= 81.25%] [Generator loss= 3.157318]
# Epoch 170: [Discriminator loss= 0.051626, Discriminator accuracy= 100.00%] [Generator loss= 4.329565]
# Epoch 171: [Discriminator loss= 0.209054, Discriminator accuracy= 90.62%] [Generator loss= 2.936820]
# Epoch 172: [Discriminator loss= 0.295241, Discriminator accuracy= 87.50%] [Generator loss= 3.778624]
# Epoch 173: [Discriminator loss= 0.138751, Discriminator accuracy= 100.00%] [Generator loss= 4.231935]
# Epoch 174: [Discriminator loss= 0.548448, Discriminator accuracy= 75.00%] [Generator loss= 3.002136]
# Epoch 175: [Discriminator loss= 0.075120, Discriminator accuracy= 100.00%] [Generator loss= 3.712045]
# Epoch 176: [Discriminator loss= 0.128638, Discriminator accuracy= 100.00%] [Generator loss= 3.929524]
# Epoch 177: [Discriminator loss= 0.730874, Discriminator accuracy= 65.62%] [Generator loss= 2.289829]
# Epoch 178: [Discriminator loss= 0.286329, Discriminator accuracy= 84.38%] [Generator loss= 3.339053]
# Epoch 179: [Discriminator loss= 0.120680, Discriminator accuracy= 100.00%] [Generator loss= 3.145650]
# Epoch 180: [Discriminator loss= 0.314753, Discriminator accuracy= 84.38%] [Generator loss= 2.697176]
# Epoch 181: [Discriminator loss= 0.097748, Discriminator accuracy= 100.00%] [Generator loss= 2.892976]
# Epoch 182: [Discriminator loss= 0.193903, Discriminator accuracy= 93.75%] [Generator loss= 3.193872]
# Epoch 183: [Discriminator loss= 0.396605, Discriminator accuracy= 75.00%] [Generator loss= 3.486899]
# Epoch 184: [Discriminator loss= 0.346979, Discriminator accuracy= 81.25%] [Generator loss= 2.180981]
# Epoch 185: [Discriminator loss= 0.172028, Discriminator accuracy= 90.62%] [Generator loss= 3.123565]
# Epoch 186: [Discriminator loss= 0.286879, Discriminator accuracy= 90.62%] [Generator loss= 2.602912]
# Epoch 187: [Discriminator loss= 0.185944, Discriminator accuracy= 93.75%] [Generator loss= 3.199371]
# Epoch 188: [Discriminator loss= 0.224340, Discriminator accuracy= 93.75%] [Generator loss= 2.513015]
# Epoch 189: [Discriminator loss= 0.198869, Discriminator accuracy= 93.75%] [Generator loss= 3.992413]
# Epoch 190: [Discriminator loss= 0.607220, Discriminator accuracy= 75.00%] [Generator loss= 1.739593]
# Epoch 191: [Discriminator loss= 0.212148, Discriminator accuracy= 93.75%] [Generator loss= 3.404757]
# Epoch 192: [Discriminator loss= 0.205763, Discriminator accuracy= 96.88%] [Generator loss= 2.677999]
# Epoch 193: [Discriminator loss= 0.215205, Discriminator accuracy= 93.75%] [Generator loss= 2.452387]
# Epoch 194: [Discriminator loss= 0.263612, Discriminator accuracy= 84.38%] [Generator loss= 4.173039]
# Epoch 195: [Discriminator loss= 1.637843, Discriminator accuracy= 25.00%] [Generator loss= 0.604513]
# Epoch 196: [Discriminator loss= 1.099321, Discriminator accuracy= 59.38%] [Generator loss= 1.110155]
# Epoch 197: [Discriminator loss= 0.317370, Discriminator accuracy= 78.12%] [Generator loss= 3.029160]
# Epoch 198: [Discriminator loss= 0.143293, Discriminator accuracy= 96.88%] [Generator loss= 2.921499]
# Epoch 199: [Discriminator loss= 0.148330, Discriminator accuracy= 96.88%] [Generator loss= 2.725941]
# Epoch 200: [Discriminator loss= 0.111762, Discriminator accuracy= 100.00%] [Generator loss= 2.813399]
# Epoch 201: [Discriminator loss= 0.164076, Discriminator accuracy= 100.00%] [Generator loss= 2.640756]
# Epoch 202: [Discriminator loss= 0.129948, Discriminator accuracy= 100.00%] [Generator loss= 2.566287]
# Epoch 203: [Discriminator loss= 0.149697, Discriminator accuracy= 96.88%] [Generator loss= 2.425727]
# Epoch 204: [Discriminator loss= 0.166488, Discriminator accuracy= 93.75%] [Generator loss= 2.603509]
# Epoch 205: [Discriminator loss= 0.336185, Discriminator accuracy= 84.38%] [Generator loss= 3.291852]
# Epoch 206: [Discriminator loss= 0.689292, Discriminator accuracy= 68.75%] [Generator loss= 1.375667]
# Epoch 207: [Discriminator loss= 0.362105, Discriminator accuracy= 81.25%] [Generator loss= 3.315294]
# Epoch 208: [Discriminator loss= 0.745526, Discriminator accuracy= 50.00%] [Generator loss= 1.169850]
# Epoch 209: [Discriminator loss= 0.362929, Discriminator accuracy= 78.12%] [Generator loss= 2.372615]
# Epoch 210: [Discriminator loss= 0.254075, Discriminator accuracy= 90.62%] [Generator loss= 2.956413]
# Epoch 211: [Discriminator loss= 0.220534, Discriminator accuracy= 93.75%] [Generator loss= 2.004719]
# Epoch 212: [Discriminator loss= 0.359043, Discriminator accuracy= 75.00%] [Generator loss= 3.039024]
# Epoch 213: [Discriminator loss= 0.277792, Discriminator accuracy= 90.62%] [Generator loss= 2.909132]
# Epoch 214: [Discriminator loss= 0.259208, Discriminator accuracy= 90.62%] [Generator loss= 1.735313]
# Epoch 215: [Discriminator loss= 0.568436, Discriminator accuracy= 62.50%] [Generator loss= 2.970105]
# Epoch 216: [Discriminator loss= 0.243319, Discriminator accuracy= 96.88%] [Generator loss= 2.327431]
# Epoch 217: [Discriminator loss= 0.226992, Discriminator accuracy= 90.62%] [Generator loss= 1.742944]
# Epoch 218: [Discriminator loss= 0.229535, Discriminator accuracy= 87.50%] [Generator loss= 2.843794]
# Epoch 219: [Discriminator loss= 0.317880, Discriminator accuracy= 93.75%] [Generator loss= 2.183733]
# Epoch 220: [Discriminator loss= 0.292935, Discriminator accuracy= 96.88%] [Generator loss= 3.515463]
# Epoch 221: [Discriminator loss= 0.595129, Discriminator accuracy= 62.50%] [Generator loss= 1.981592]
# Epoch 222: [Discriminator loss= 0.241058, Discriminator accuracy= 93.75%] [Generator loss= 3.138480]
# Epoch 223: [Discriminator loss= 0.768135, Discriminator accuracy= 56.25%] [Generator loss= 1.415628]
# Epoch 224: [Discriminator loss= 0.291830, Discriminator accuracy= 87.50%] [Generator loss= 3.222585]
# Epoch 225: [Discriminator loss= 0.292566, Discriminator accuracy= 93.75%] [Generator loss= 2.241259]
# Epoch 226: [Discriminator loss= 0.152370, Discriminator accuracy= 100.00%] [Generator loss= 2.312689]
# Epoch 227: [Discriminator loss= 0.266433, Discriminator accuracy= 87.50%] [Generator loss= 2.060586]
# Epoch 228: [Discriminator loss= 0.368408, Discriminator accuracy= 78.12%] [Generator loss= 3.813697]
# Epoch 229: [Discriminator loss= 1.327753, Discriminator accuracy= 46.88%] [Generator loss= 0.738947]
# Epoch 230: [Discriminator loss= 0.479262, Discriminator accuracy= 71.88%] [Generator loss= 2.973437]
# Epoch 231: [Discriminator loss= 0.540219, Discriminator accuracy= 62.50%] [Generator loss= 1.833979]
# Epoch 232: [Discriminator loss= 0.339045, Discriminator accuracy= 78.12%] [Generator loss= 2.452114]
# Epoch 233: [Discriminator loss= 0.317208, Discriminator accuracy= 93.75%] [Generator loss= 2.414346]
# Epoch 234: [Discriminator loss= 0.358850, Discriminator accuracy= 81.25%] [Generator loss= 1.864543]
# Epoch 235: [Discriminator loss= 0.301171, Discriminator accuracy= 87.50%] [Generator loss= 2.354078]
# Epoch 236: [Discriminator loss= 0.449039, Discriminator accuracy= 75.00%] [Generator loss= 2.442912]
# Epoch 237: [Discriminator loss= 0.605582, Discriminator accuracy= 62.50%] [Generator loss= 2.514070]
# Epoch 238: [Discriminator loss= 0.414757, Discriminator accuracy= 78.12%] [Generator loss= 2.852866]
# Epoch 239: [Discriminator loss= 0.591196, Discriminator accuracy= 75.00%] [Generator loss= 1.720856]
# Epoch 240: [Discriminator loss= 0.527366, Discriminator accuracy= 68.75%] [Generator loss= 2.347792]
# Epoch 241: [Discriminator loss= 0.480137, Discriminator accuracy= 78.12%] [Generator loss= 2.198652]
# Epoch 242: [Discriminator loss= 0.587994, Discriminator accuracy= 62.50%] [Generator loss= 2.013986]
# Epoch 243: [Discriminator loss= 0.711796, Discriminator accuracy= 59.38%] [Generator loss= 2.466455]
# Epoch 244: [Discriminator loss= 0.624227, Discriminator accuracy= 65.62%] [Generator loss= 1.882653]
# Epoch 245: [Discriminator loss= 0.400183, Discriminator accuracy= 78.12%] [Generator loss= 2.241396]
# Epoch 246: [Discriminator loss= 0.832827, Discriminator accuracy= 56.25%] [Generator loss= 1.442054]
# Epoch 247: [Discriminator loss= 0.635766, Discriminator accuracy= 62.50%] [Generator loss= 2.263141]
# Epoch 248: [Discriminator loss= 0.736517, Discriminator accuracy= 50.00%] [Generator loss= 1.223656]
# Epoch 249: [Discriminator loss= 0.279899, Discriminator accuracy= 87.50%] [Generator loss= 2.182024]
# Epoch 250: [Discriminator loss= 1.021527, Discriminator accuracy= 34.38%] [Generator loss= 0.603838]
# Epoch 251: [Discriminator loss= 0.517477, Discriminator accuracy= 59.38%] [Generator loss= 2.073649]
# Epoch 252: [Discriminator loss= 0.657937, Discriminator accuracy= 59.38%] [Generator loss= 1.295116]
# Epoch 253: [Discriminator loss= 0.495671, Discriminator accuracy= 81.25%] [Generator loss= 1.709765]
# Epoch 254: [Discriminator loss= 0.730468, Discriminator accuracy= 50.00%] [Generator loss= 1.103408]
# Epoch 255: [Discriminator loss= 0.593648, Discriminator accuracy= 62.50%] [Generator loss= 1.257212]
# Epoch 256: [Discriminator loss= 0.518602, Discriminator accuracy= 68.75%] [Generator loss= 1.402011]
# Epoch 257: [Discriminator loss= 0.934863, Discriminator accuracy= 34.38%] [Generator loss= 1.049451]
# Epoch 258: [Discriminator loss= 0.708023, Discriminator accuracy= 56.25%] [Generator loss= 1.265290]
# Epoch 259: [Discriminator loss= 0.719579, Discriminator accuracy= 59.38%] [Generator loss= 1.024132]
# Epoch 260: [Discriminator loss= 0.689541, Discriminator accuracy= 50.00%] [Generator loss= 1.266792]
# Epoch 261: [Discriminator loss= 0.876927, Discriminator accuracy= 40.62%] [Generator loss= 0.869808]
# Epoch 262: [Discriminator loss= 0.684347, Discriminator accuracy= 46.88%] [Generator loss= 1.156764]
# Epoch 263: [Discriminator loss= 0.818588, Discriminator accuracy= 40.62%] [Generator loss= 1.015757]
# Epoch 264: [Discriminator loss= 0.599504, Discriminator accuracy= 59.38%] [Generator loss= 1.322996]
# Epoch 265: [Discriminator loss= 0.864419, Discriminator accuracy= 34.38%] [Generator loss= 0.965791]
# Epoch 266: [Discriminator loss= 0.904415, Discriminator accuracy= 34.38%] [Generator loss= 0.765745]
# Epoch 267: [Discriminator loss= 0.508685, Discriminator accuracy= 75.00%] [Generator loss= 1.229134]
# Epoch 268: [Discriminator loss= 0.703662, Discriminator accuracy= 56.25%] [Generator loss= 0.941380]
# Epoch 269: [Discriminator loss= 0.592505, Discriminator accuracy= 75.00%] [Generator loss= 0.924653]
# Epoch 270: [Discriminator loss= 0.637297, Discriminator accuracy= 53.12%] [Generator loss= 1.054409]
# Epoch 271: [Discriminator loss= 0.891172, Discriminator accuracy= 37.50%] [Generator loss= 0.572005]
# Epoch 272: [Discriminator loss= 0.719510, Discriminator accuracy= 50.00%] [Generator loss= 0.959811]
# Epoch 273: [Discriminator loss= 0.713575, Discriminator accuracy= 59.38%] [Generator loss= 0.944862]
# Epoch 274: [Discriminator loss= 0.548887, Discriminator accuracy= 71.88%] [Generator loss= 1.120659]
# Epoch 275: [Discriminator loss= 0.871640, Discriminator accuracy= 34.38%] [Generator loss= 0.760159]
# Epoch 276: [Discriminator loss= 0.648527, Discriminator accuracy= 59.38%] [Generator loss= 1.231526]
# Epoch 277: [Discriminator loss= 0.827140, Discriminator accuracy= 31.25%] [Generator loss= 0.714105]
# Epoch 278: [Discriminator loss= 0.744912, Discriminator accuracy= 43.75%] [Generator loss= 0.739294]
# Epoch 279: [Discriminator loss= 0.621471, Discriminator accuracy= 62.50%] [Generator loss= 0.888503]
# Epoch 280: [Discriminator loss= 0.693228, Discriminator accuracy= 43.75%] [Generator loss= 0.952846]
# Epoch 281: [Discriminator loss= 0.780804, Discriminator accuracy= 34.38%] [Generator loss= 0.871703]
# Epoch 282: [Discriminator loss= 0.748721, Discriminator accuracy= 40.62%] [Generator loss= 0.805879]
# Epoch 283: [Discriminator loss= 0.573614, Discriminator accuracy= 71.88%] [Generator loss= 1.084323]
# Epoch 284: [Discriminator loss= 1.117457, Discriminator accuracy= 21.88%] [Generator loss= 0.453496]
# Epoch 285: [Discriminator loss= 0.727943, Discriminator accuracy= 50.00%] [Generator loss= 0.594970]
# Epoch 286: [Discriminator loss= 0.696601, Discriminator accuracy= 43.75%] [Generator loss= 0.789146]
# Epoch 287: [Discriminator loss= 0.702948, Discriminator accuracy= 50.00%] [Generator loss= 0.839064]
# Epoch 288: [Discriminator loss= 0.754221, Discriminator accuracy= 40.62%] [Generator loss= 0.733859]
# Epoch 289: [Discriminator loss= 0.691593, Discriminator accuracy= 53.12%] [Generator loss= 0.693528]
# Epoch 290: [Discriminator loss= 0.699514, Discriminator accuracy= 50.00%] [Generator loss= 0.765543]
# Epoch 291: [Discriminator loss= 0.713982, Discriminator accuracy= 53.12%] [Generator loss= 0.694408]
# Epoch 292: [Discriminator loss= 0.685163, Discriminator accuracy= 43.75%] [Generator loss= 0.751820]
# Epoch 293: [Discriminator loss= 0.651256, Discriminator accuracy= 50.00%] [Generator loss= 0.765170]
# Epoch 294: [Discriminator loss= 0.689644, Discriminator accuracy= 50.00%] [Generator loss= 0.794642]
# Epoch 295: [Discriminator loss= 0.663342, Discriminator accuracy= 53.12%] [Generator loss= 0.800144]
# Epoch 296: [Discriminator loss= 0.632919, Discriminator accuracy= 53.12%] [Generator loss= 0.880704]
# Epoch 297: [Discriminator loss= 0.847970, Discriminator accuracy= 31.25%] [Generator loss= 0.724989]
# Epoch 298: [Discriminator loss= 0.688947, Discriminator accuracy= 43.75%] [Generator loss= 0.740958]
# Epoch 299: [Discriminator loss= 0.641510, Discriminator accuracy= 56.25%] [Generator loss= 0.916048]
# Epoch 300: [Discriminator loss= 0.745393, Discriminator accuracy= 37.50%] [Generator loss= 0.772491]
# Epoch 301: [Discriminator loss= 0.671015, Discriminator accuracy= 43.75%] [Generator loss= 0.818499]
# Epoch 302: [Discriminator loss= 0.742708, Discriminator accuracy= 34.38%] [Generator loss= 0.827217]
# Epoch 303: [Discriminator loss= 0.741701, Discriminator accuracy= 37.50%] [Generator loss= 0.776943]
# Epoch 304: [Discriminator loss= 0.751411, Discriminator accuracy= 34.38%] [Generator loss= 0.711949]
# Epoch 305: [Discriminator loss= 0.724462, Discriminator accuracy= 40.62%] [Generator loss= 0.683379]
# Epoch 306: [Discriminator loss= 0.777600, Discriminator accuracy= 37.50%] [Generator loss= 0.637221]
# Epoch 307: [Discriminator loss= 0.636856, Discriminator accuracy= 53.12%] [Generator loss= 0.752112]
# Epoch 308: [Discriminator loss= 0.708244, Discriminator accuracy= 43.75%] [Generator loss= 0.734914]
# Epoch 309: [Discriminator loss= 0.767589, Discriminator accuracy= 43.75%] [Generator loss= 0.650153]
# Epoch 310: [Discriminator loss= 0.712238, Discriminator accuracy= 43.75%] [Generator loss= 0.671376]
# Epoch 311: [Discriminator loss= 0.724637, Discriminator accuracy= 40.62%] [Generator loss= 0.646752]
# Epoch 312: [Discriminator loss= 0.649977, Discriminator accuracy= 59.38%] [Generator loss= 0.757245]
# Epoch 313: [Discriminator loss= 0.699079, Discriminator accuracy= 46.88%] [Generator loss= 0.703371]
# Epoch 314: [Discriminator loss= 0.689550, Discriminator accuracy= 50.00%] [Generator loss= 0.722991]
# Epoch 315: [Discriminator loss= 0.705898, Discriminator accuracy= 46.88%] [Generator loss= 0.658720]
# Epoch 316: [Discriminator loss= 0.723263, Discriminator accuracy= 46.88%] [Generator loss= 0.696085]
# Epoch 317: [Discriminator loss= 0.659835, Discriminator accuracy= 50.00%] [Generator loss= 0.772780]
# Epoch 318: [Discriminator loss= 0.740858, Discriminator accuracy= 40.62%] [Generator loss= 0.679650]
# Epoch 319: [Discriminator loss= 0.669222, Discriminator accuracy= 50.00%] [Generator loss= 0.694796]
# Epoch 320: [Discriminator loss= 0.679965, Discriminator accuracy= 50.00%] [Generator loss= 0.698776]
# Epoch 321: [Discriminator loss= 0.739617, Discriminator accuracy= 43.75%] [Generator loss= 0.669867]
# Epoch 322: [Discriminator loss= 0.701880, Discriminator accuracy= 46.88%] [Generator loss= 0.651509]
# Epoch 323: [Discriminator loss= 0.683998, Discriminator accuracy= 50.00%] [Generator loss= 0.680791]
# Epoch 324: [Discriminator loss= 0.707620, Discriminator accuracy= 40.62%] [Generator loss= 0.677361]
# Epoch 325: [Discriminator loss= 0.701508, Discriminator accuracy= 46.88%] [Generator loss= 0.679369]
# Epoch 326: [Discriminator loss= 0.673979, Discriminator accuracy= 53.12%] [Generator loss= 0.700377]
# Epoch 327: [Discriminator loss= 0.725650, Discriminator accuracy= 40.62%] [Generator loss= 0.670134]
# Epoch 328: [Discriminator loss= 0.736674, Discriminator accuracy= 34.38%] [Generator loss= 0.675685]
# Epoch 329: [Discriminator loss= 0.695616, Discriminator accuracy= 43.75%] [Generator loss= 0.644335]
# Epoch 330: [Discriminator loss= 0.741243, Discriminator accuracy= 37.50%] [Generator loss= 0.645858]
# Epoch 331: [Discriminator loss= 0.709055, Discriminator accuracy= 46.88%] [Generator loss= 0.650748]
# Epoch 332: [Discriminator loss= 0.674750, Discriminator accuracy= 46.88%] [Generator loss= 0.688221]
# Epoch 333: [Discriminator loss= 0.725070, Discriminator accuracy= 34.38%] [Generator loss= 0.659403]
# Epoch 334: [Discriminator loss= 0.680002, Discriminator accuracy= 50.00%] [Generator loss= 0.651062]
# Epoch 335: [Discriminator loss= 0.699995, Discriminator accuracy= 43.75%] [Generator loss= 0.695214]
# Epoch 336: [Discriminator loss= 0.678315, Discriminator accuracy= 43.75%] [Generator loss= 0.689927]
# Epoch 337: [Discriminator loss= 0.686676, Discriminator accuracy= 50.00%] [Generator loss= 0.698599]
# Epoch 338: [Discriminator loss= 0.668608, Discriminator accuracy= 50.00%] [Generator loss= 0.696837]
# Epoch 339: [Discriminator loss= 0.674409, Discriminator accuracy= 53.12%] [Generator loss= 0.689708]
# Epoch 340: [Discriminator loss= 0.703444, Discriminator accuracy= 46.88%] [Generator loss= 0.665147]
# Epoch 341: [Discriminator loss= 0.726152, Discriminator accuracy= 43.75%] [Generator loss= 0.691835]
# Epoch 342: [Discriminator loss= 0.737245, Discriminator accuracy= 40.62%] [Generator loss= 0.649153]
# Epoch 343: [Discriminator loss= 0.711632, Discriminator accuracy= 43.75%] [Generator loss= 0.627625]
# Epoch 344: [Discriminator loss= 0.666289, Discriminator accuracy= 50.00%] [Generator loss= 0.661263]
# Epoch 345: [Discriminator loss= 0.722486, Discriminator accuracy= 43.75%] [Generator loss= 0.634581]
# Epoch 346: [Discriminator loss= 0.709642, Discriminator accuracy= 46.88%] [Generator loss= 0.633909]
# Epoch 347: [Discriminator loss= 0.692929, Discriminator accuracy= 50.00%] [Generator loss= 0.630959]
# Epoch 348: [Discriminator loss= 0.699638, Discriminator accuracy= 43.75%] [Generator loss= 0.642149]
# Epoch 349: [Discriminator loss= 0.683836, Discriminator accuracy= 50.00%] [Generator loss= 0.627604]
# Epoch 350: [Discriminator loss= 0.697109, Discriminator accuracy= 50.00%] [Generator loss= 0.629520]
# Epoch 351: [Discriminator loss= 0.680104, Discriminator accuracy= 50.00%] [Generator loss= 0.640267]
# Epoch 352: [Discriminator loss= 0.686458, Discriminator accuracy= 50.00%] [Generator loss= 0.655368]
# Epoch 353: [Discriminator loss= 0.712475, Discriminator accuracy= 40.62%] [Generator loss= 0.626677]
# Epoch 354: [Discriminator loss= 0.716880, Discriminator accuracy= 43.75%] [Generator loss= 0.626364]
# Epoch 355: [Discriminator loss= 0.682692, Discriminator accuracy= 46.88%] [Generator loss= 0.628622]
# Epoch 356: [Discriminator loss= 0.675463, Discriminator accuracy= 53.12%] [Generator loss= 0.630204]
# Epoch 357: [Discriminator loss= 0.679687, Discriminator accuracy= 43.75%] [Generator loss= 0.623179]
# Epoch 358: [Discriminator loss= 0.660198, Discriminator accuracy= 53.12%] [Generator loss= 0.622841]
# Epoch 359: [Discriminator loss= 0.710284, Discriminator accuracy= 43.75%] [Generator loss= 0.627347]
# Epoch 360: [Discriminator loss= 0.723175, Discriminator accuracy= 34.38%] [Generator loss= 0.631561]
# Epoch 361: [Discriminator loss= 0.708100, Discriminator accuracy= 43.75%] [Generator loss= 0.601571]
# Epoch 362: [Discriminator loss= 0.664985, Discriminator accuracy= 50.00%] [Generator loss= 0.610941]
# Epoch 363: [Discriminator loss= 0.689201, Discriminator accuracy= 50.00%] [Generator loss= 0.642642]
# Epoch 364: [Discriminator loss= 0.658143, Discriminator accuracy= 50.00%] [Generator loss= 0.653333]
# Epoch 365: [Discriminator loss= 0.663435, Discriminator accuracy= 53.12%] [Generator loss= 0.653209]
# Epoch 366: [Discriminator loss= 0.725867, Discriminator accuracy= 40.62%] [Generator loss= 0.643798]
# Epoch 367: [Discriminator loss= 0.677943, Discriminator accuracy= 53.12%] [Generator loss= 0.631853]
# Epoch 368: [Discriminator loss= 0.719076, Discriminator accuracy= 37.50%] [Generator loss= 0.612448]
# Epoch 369: [Discriminator loss= 0.675226, Discriminator accuracy= 50.00%] [Generator loss= 0.645938]
# Epoch 370: [Discriminator loss= 0.675654, Discriminator accuracy= 46.88%] [Generator loss= 0.653644]
# Epoch 371: [Discriminator loss= 0.695110, Discriminator accuracy= 43.75%] [Generator loss= 0.633528]
# Epoch 372: [Discriminator loss= 0.693107, Discriminator accuracy= 43.75%] [Generator loss= 0.623040]
# Epoch 373: [Discriminator loss= 0.649458, Discriminator accuracy= 50.00%] [Generator loss= 0.648825]
# Epoch 374: [Discriminator loss= 0.690162, Discriminator accuracy= 40.62%] [Generator loss= 0.647567]
# Epoch 375: [Discriminator loss= 0.675557, Discriminator accuracy= 50.00%] [Generator loss= 0.660164]
# Epoch 376: [Discriminator loss= 0.675691, Discriminator accuracy= 50.00%] [Generator loss= 0.685385]
# Epoch 377: [Discriminator loss= 0.657534, Discriminator accuracy= 46.88%] [Generator loss= 0.688942]
# Epoch 378: [Discriminator loss= 0.686869, Discriminator accuracy= 50.00%] [Generator loss= 0.678495]
# Epoch 379: [Discriminator loss= 0.683421, Discriminator accuracy= 40.62%] [Generator loss= 0.667302]
# Epoch 380: [Discriminator loss= 0.681448, Discriminator accuracy= 46.88%] [Generator loss= 0.656986]
# Epoch 381: [Discriminator loss= 0.690768, Discriminator accuracy= 50.00%] [Generator loss= 0.651996]
# Epoch 382: [Discriminator loss= 0.678219, Discriminator accuracy= 46.88%] [Generator loss= 0.653653]
# Epoch 383: [Discriminator loss= 0.687640, Discriminator accuracy= 40.62%] [Generator loss= 0.652357]
# Epoch 384: [Discriminator loss= 0.663333, Discriminator accuracy= 50.00%] [Generator loss= 0.643042]
# Epoch 385: [Discriminator loss= 0.676204, Discriminator accuracy= 53.12%] [Generator loss= 0.686903]
# Epoch 386: [Discriminator loss= 0.673741, Discriminator accuracy= 53.12%] [Generator loss= 0.704288]
# Epoch 387: [Discriminator loss= 0.627200, Discriminator accuracy= 62.50%] [Generator loss= 0.725891]
# Epoch 388: [Discriminator loss= 0.663032, Discriminator accuracy= 46.88%] [Generator loss= 0.725304]
# Epoch 389: [Discriminator loss= 0.678420, Discriminator accuracy= 46.88%] [Generator loss= 0.681353]
# Epoch 390: [Discriminator loss= 0.691350, Discriminator accuracy= 46.88%] [Generator loss= 0.666839]
# Epoch 391: [Discriminator loss= 0.677069, Discriminator accuracy= 50.00%] [Generator loss= 0.633307]
# Epoch 392: [Discriminator loss= 0.714014, Discriminator accuracy= 43.75%] [Generator loss= 0.630331]
# Epoch 393: [Discriminator loss= 0.645416, Discriminator accuracy= 56.25%] [Generator loss= 0.627905]
# Epoch 394: [Discriminator loss= 0.666126, Discriminator accuracy= 50.00%] [Generator loss= 0.651096]
# Epoch 395: [Discriminator loss= 0.651665, Discriminator accuracy= 53.12%] [Generator loss= 0.635333]
# Epoch 396: [Discriminator loss= 0.659566, Discriminator accuracy= 56.25%] [Generator loss= 0.658771]
# Epoch 397: [Discriminator loss= 0.671138, Discriminator accuracy= 53.12%] [Generator loss= 0.663266]
# Epoch 398: [Discriminator loss= 0.659503, Discriminator accuracy= 62.50%] [Generator loss= 0.681379]
# Epoch 399: [Discriminator loss= 0.683024, Discriminator accuracy= 50.00%] [Generator loss= 0.635927]
# Epoch 400: [Discriminator loss= 0.676693, Discriminator accuracy= 50.00%] [Generator loss= 0.641310]
# Epoch 401: [Discriminator loss= 0.702564, Discriminator accuracy= 43.75%] [Generator loss= 0.625904]
# Epoch 402: [Discriminator loss= 0.679915, Discriminator accuracy= 50.00%] [Generator loss= 0.623270]
# Epoch 403: [Discriminator loss= 0.665570, Discriminator accuracy= 53.12%] [Generator loss= 0.647116]
# Epoch 404: [Discriminator loss= 0.653924, Discriminator accuracy= 50.00%] [Generator loss= 0.642666]
# Epoch 405: [Discriminator loss= 0.678058, Discriminator accuracy= 50.00%] [Generator loss= 0.654777]
# Epoch 406: [Discriminator loss= 0.686737, Discriminator accuracy= 34.38%] [Generator loss= 0.691368]
# Epoch 407: [Discriminator loss= 0.702622, Discriminator accuracy= 46.88%] [Generator loss= 0.673635]
# Epoch 408: [Discriminator loss= 0.680409, Discriminator accuracy= 46.88%] [Generator loss= 0.669228]
# Epoch 409: [Discriminator loss= 0.701428, Discriminator accuracy= 43.75%] [Generator loss= 0.675614]
# Epoch 410: [Discriminator loss= 0.683960, Discriminator accuracy= 43.75%] [Generator loss= 0.654820]
# Epoch 411: [Discriminator loss= 0.704254, Discriminator accuracy= 40.62%] [Generator loss= 0.647722]
# Epoch 412: [Discriminator loss= 0.663355, Discriminator accuracy= 46.88%] [Generator loss= 0.650319]
# Epoch 413: [Discriminator loss= 0.663483, Discriminator accuracy= 50.00%] [Generator loss= 0.682374]
# Epoch 414: [Discriminator loss= 0.673890, Discriminator accuracy= 43.75%] [Generator loss= 0.675144]
# Epoch 415: [Discriminator loss= 0.650410, Discriminator accuracy= 50.00%] [Generator loss= 0.671034]
# Epoch 416: [Discriminator loss= 0.670726, Discriminator accuracy= 43.75%] [Generator loss= 0.660121]
# Epoch 417: [Discriminator loss= 0.661537, Discriminator accuracy= 46.88%] [Generator loss= 0.643928]
# Epoch 418: [Discriminator loss= 0.672480, Discriminator accuracy= 50.00%] [Generator loss= 0.680853]
# Epoch 419: [Discriminator loss= 0.680975, Discriminator accuracy= 50.00%] [Generator loss= 0.697087]
# Epoch 420: [Discriminator loss= 0.696201, Discriminator accuracy= 50.00%] [Generator loss= 0.673107]
# Epoch 421: [Discriminator loss= 0.695316, Discriminator accuracy= 46.88%] [Generator loss= 0.673340]
# Epoch 422: [Discriminator loss= 0.648077, Discriminator accuracy= 50.00%] [Generator loss= 0.652125]
# Epoch 423: [Discriminator loss= 0.656781, Discriminator accuracy= 53.12%] [Generator loss= 0.654395]
# Epoch 424: [Discriminator loss= 0.683605, Discriminator accuracy= 40.62%] [Generator loss= 0.652369]
# Epoch 425: [Discriminator loss= 0.677901, Discriminator accuracy= 43.75%] [Generator loss= 0.650639]
# Epoch 426: [Discriminator loss= 0.624977, Discriminator accuracy= 56.25%] [Generator loss= 0.653446]
# Epoch 427: [Discriminator loss= 0.644221, Discriminator accuracy= 53.12%] [Generator loss= 0.664519]
# Epoch 428: [Discriminator loss= 0.652706, Discriminator accuracy= 53.12%] [Generator loss= 0.672164]
# Epoch 429: [Discriminator loss= 0.700375, Discriminator accuracy= 56.25%] [Generator loss= 0.680385]
# Epoch 430: [Discriminator loss= 0.674200, Discriminator accuracy= 62.50%] [Generator loss= 0.680337]
# Epoch 431: [Discriminator loss= 0.711650, Discriminator accuracy= 53.12%] [Generator loss= 0.649787]
# Epoch 432: [Discriminator loss= 0.684124, Discriminator accuracy= 53.12%] [Generator loss= 0.676251]
# Epoch 433: [Discriminator loss= 0.676432, Discriminator accuracy= 50.00%] [Generator loss= 0.684001]
# Epoch 434: [Discriminator loss= 0.695196, Discriminator accuracy= 43.75%] [Generator loss= 0.670227]
# Epoch 435: [Discriminator loss= 0.659070, Discriminator accuracy= 53.12%] [Generator loss= 0.669592]
# Epoch 436: [Discriminator loss= 0.688934, Discriminator accuracy= 46.88%] [Generator loss= 0.674508]
# Epoch 437: [Discriminator loss= 0.661114, Discriminator accuracy= 53.12%] [Generator loss= 0.658870]
# Epoch 438: [Discriminator loss= 0.644692, Discriminator accuracy= 56.25%] [Generator loss= 0.687109]
# Epoch 439: [Discriminator loss= 0.690253, Discriminator accuracy= 40.62%] [Generator loss= 0.657991]
# Epoch 440: [Discriminator loss= 0.670141, Discriminator accuracy= 53.12%] [Generator loss= 0.652495]
# Epoch 441: [Discriminator loss= 0.683682, Discriminator accuracy= 46.88%] [Generator loss= 0.657254]
# Epoch 442: [Discriminator loss= 0.649584, Discriminator accuracy= 43.75%] [Generator loss= 0.671705]
# Epoch 443: [Discriminator loss= 0.668775, Discriminator accuracy= 50.00%] [Generator loss= 0.687652]
# Epoch 444: [Discriminator loss= 0.678210, Discriminator accuracy= 50.00%] [Generator loss= 0.698573]
# ...
# Epoch 4845: [Discriminator loss= 0.629167, Discriminator accuracy= 68.75%] [Generator loss= 0.895595]
# Epoch 4846: [Discriminator loss= 0.691499, Discriminator accuracy= 50.00%] [Generator loss= 0.902967]
# Epoch 4847: [Discriminator loss= 0.624951, Discriminator accuracy= 68.75%] [Generator loss= 0.938385]
# Epoch 4848: [Discriminator loss= 0.664818, Discriminator accuracy= 56.25%] [Generator loss= 0.904688]
# Epoch 4849: [Discriminator loss= 0.723403, Discriminator accuracy= 46.88%] [Generator loss= 0.833354]
# Epoch 4850: [Discriminator loss= 0.557747, Discriminator accuracy= 75.00%] [Generator loss= 0.865798]
# Epoch 4851: [Discriminator loss= 0.698552, Discriminator accuracy= 56.25%] [Generator loss= 0.828615]
# Epoch 4852: [Discriminator loss= 0.673834, Discriminator accuracy= 56.25%] [Generator loss= 0.838303]
# Epoch 4853: [Discriminator loss= 0.641918, Discriminator accuracy= 68.75%] [Generator loss= 0.871326]
# Epoch 4854: [Discriminator loss= 0.648265, Discriminator accuracy= 71.88%] [Generator loss= 0.970867]
# Epoch 4855: [Discriminator loss= 0.654096, Discriminator accuracy= 53.12%] [Generator loss= 0.925924]
# Epoch 4856: [Discriminator loss= 0.709732, Discriminator accuracy= 56.25%] [Generator loss= 0.880453]
# Epoch 4857: [Discriminator loss= 0.626363, Discriminator accuracy= 62.50%] [Generator loss= 0.830495]
# Epoch 4858: [Discriminator loss= 0.655255, Discriminator accuracy= 68.75%] [Generator loss= 0.882322]
# Epoch 4859: [Discriminator loss= 0.653921, Discriminator accuracy= 65.62%] [Generator loss= 0.865549]
# Epoch 4860: [Discriminator loss= 0.652634, Discriminator accuracy= 59.38%] [Generator loss= 0.918175]
# Epoch 4861: [Discriminator loss= 0.554422, Discriminator accuracy= 75.00%] [Generator loss= 0.880983]
# Epoch 4862: [Discriminator loss= 0.735017, Discriminator accuracy= 43.75%] [Generator loss= 0.830569]
# Epoch 4863: [Discriminator loss= 0.717893, Discriminator accuracy= 59.38%] [Generator loss= 0.835996]
# Epoch 4864: [Discriminator loss= 0.572724, Discriminator accuracy= 59.38%] [Generator loss= 0.915808]
# Epoch 4865: [Discriminator loss= 0.700385, Discriminator accuracy= 53.12%] [Generator loss= 0.932195]
# Epoch 4866: [Discriminator loss= 0.652595, Discriminator accuracy= 56.25%] [Generator loss= 0.899609]
# Epoch 4867: [Discriminator loss= 0.680950, Discriminator accuracy= 53.12%] [Generator loss= 0.840496]
# Epoch 4868: [Discriminator loss= 0.631281, Discriminator accuracy= 56.25%] [Generator loss= 0.887535]
# Epoch 4869: [Discriminator loss= 0.701183, Discriminator accuracy= 59.38%] [Generator loss= 0.948191]
# Epoch 4870: [Discriminator loss= 0.590291, Discriminator accuracy= 68.75%] [Generator loss= 0.904428]
# Epoch 4871: [Discriminator loss= 0.660634, Discriminator accuracy= 65.62%] [Generator loss= 0.904598]
# Epoch 4872: [Discriminator loss= 0.640501, Discriminator accuracy= 65.62%] [Generator loss= 0.946322]
# Epoch 4873: [Discriminator loss= 0.678819, Discriminator accuracy= 59.38%] [Generator loss= 0.924115]
# Epoch 4874: [Discriminator loss= 0.653143, Discriminator accuracy= 56.25%] [Generator loss= 0.944134]
# Epoch 4875: [Discriminator loss= 0.620441, Discriminator accuracy= 75.00%] [Generator loss= 0.835584]
# Epoch 4876: [Discriminator loss= 0.684841, Discriminator accuracy= 56.25%] [Generator loss= 0.856852]
# Epoch 4877: [Discriminator loss= 0.668447, Discriminator accuracy= 62.50%] [Generator loss= 0.842444]
# Epoch 4878: [Discriminator loss= 0.687070, Discriminator accuracy= 62.50%] [Generator loss= 0.842425]
# Epoch 4879: [Discriminator loss= 0.682150, Discriminator accuracy= 62.50%] [Generator loss= 0.849327]
# Epoch 4880: [Discriminator loss= 0.636906, Discriminator accuracy= 68.75%] [Generator loss= 0.850345]
# Epoch 4881: [Discriminator loss= 0.598223, Discriminator accuracy= 65.62%] [Generator loss= 0.894883]
# Epoch 4882: [Discriminator loss= 0.654363, Discriminator accuracy= 56.25%] [Generator loss= 0.927722]
# Epoch 4883: [Discriminator loss= 0.724840, Discriminator accuracy= 53.12%] [Generator loss= 0.856389]
# Epoch 4884: [Discriminator loss= 0.602244, Discriminator accuracy= 71.88%] [Generator loss= 0.935862]
# Epoch 4885: [Discriminator loss= 0.613189, Discriminator accuracy= 68.75%] [Generator loss= 0.830518]
# Epoch 4886: [Discriminator loss= 0.621098, Discriminator accuracy= 68.75%] [Generator loss= 0.905340]
# Epoch 4887: [Discriminator loss= 0.607257, Discriminator accuracy= 65.62%] [Generator loss= 0.876090]
# Epoch 4888: [Discriminator loss= 0.617907, Discriminator accuracy= 65.62%] [Generator loss= 0.944558]
# Epoch 4889: [Discriminator loss= 0.649623, Discriminator accuracy= 56.25%] [Generator loss= 0.865565]
# Epoch 4890: [Discriminator loss= 0.594619, Discriminator accuracy= 75.00%] [Generator loss= 0.874584]
# Epoch 4891: [Discriminator loss= 0.736616, Discriminator accuracy= 53.12%] [Generator loss= 0.886619]
# Epoch 4892: [Discriminator loss= 0.668391, Discriminator accuracy= 71.88%] [Generator loss= 0.990878]
# Epoch 4893: [Discriminator loss= 0.650291, Discriminator accuracy= 62.50%] [Generator loss= 0.944766]
# Epoch 4894: [Discriminator loss= 0.708772, Discriminator accuracy= 56.25%] [Generator loss= 0.849744]
# Epoch 4895: [Discriminator loss= 0.641451, Discriminator accuracy= 56.25%] [Generator loss= 0.894597]
# Epoch 4896: [Discriminator loss= 0.654076, Discriminator accuracy= 62.50%] [Generator loss= 0.883175]
# Epoch 4897: [Discriminator loss= 0.673836, Discriminator accuracy= 62.50%] [Generator loss= 1.003526]
# Epoch 4898: [Discriminator loss= 0.652365, Discriminator accuracy= 59.38%] [Generator loss= 0.896215]
# Epoch 4899: [Discriminator loss= 0.711068, Discriminator accuracy= 59.38%] [Generator loss= 0.849850]
# Epoch 4900: [Discriminator loss= 0.695482, Discriminator accuracy= 53.12%] [Generator loss= 0.815602]
# Epoch 4901: [Discriminator loss= 0.655067, Discriminator accuracy= 59.38%] [Generator loss= 0.830924]
# Epoch 4902: [Discriminator loss= 0.601844, Discriminator accuracy= 81.25%] [Generator loss= 0.885461]
# Epoch 4903: [Discriminator loss= 0.653939, Discriminator accuracy= 68.75%] [Generator loss= 0.841656]
# Epoch 4904: [Discriminator loss= 0.712522, Discriminator accuracy= 56.25%] [Generator loss= 0.825705]
# Epoch 4905: [Discriminator loss= 0.699472, Discriminator accuracy= 46.88%] [Generator loss= 0.839255]
# Epoch 4906: [Discriminator loss= 0.581452, Discriminator accuracy= 75.00%] [Generator loss= 0.864073]
# Epoch 4907: [Discriminator loss= 0.605130, Discriminator accuracy= 71.88%] [Generator loss= 0.879007]
# Epoch 4908: [Discriminator loss= 0.662450, Discriminator accuracy= 62.50%] [Generator loss= 0.839730]
# Epoch 4909: [Discriminator loss= 0.653150, Discriminator accuracy= 59.38%] [Generator loss= 0.872755]
# Epoch 4910: [Discriminator loss= 0.617353, Discriminator accuracy= 65.62%] [Generator loss= 0.878114]
# Epoch 4911: [Discriminator loss= 0.736257, Discriminator accuracy= 50.00%] [Generator loss= 0.875697]
# Epoch 4912: [Discriminator loss= 0.634893, Discriminator accuracy= 68.75%] [Generator loss= 0.904084]
# Epoch 4913: [Discriminator loss= 0.698626, Discriminator accuracy= 56.25%] [Generator loss= 0.920518]
# Epoch 4914: [Discriminator loss= 0.730994, Discriminator accuracy= 56.25%] [Generator loss= 0.865394]
# Epoch 4915: [Discriminator loss= 0.684922, Discriminator accuracy= 59.38%] [Generator loss= 0.773008]
# Epoch 4916: [Discriminator loss= 0.607559, Discriminator accuracy= 59.38%] [Generator loss= 0.830450]
# Epoch 4917: [Discriminator loss= 0.734543, Discriminator accuracy= 62.50%] [Generator loss= 0.985373]
# Epoch 4918: [Discriminator loss= 0.654297, Discriminator accuracy= 56.25%] [Generator loss= 0.891925]
# Epoch 4919: [Discriminator loss= 0.713686, Discriminator accuracy= 53.12%] [Generator loss= 0.910392]
# Epoch 4920: [Discriminator loss= 0.620325, Discriminator accuracy= 68.75%] [Generator loss= 0.890047]
# Epoch 4921: [Discriminator loss= 0.604592, Discriminator accuracy= 75.00%] [Generator loss= 0.974115]
# Epoch 4922: [Discriminator loss= 0.691932, Discriminator accuracy= 46.88%] [Generator loss= 0.911291]
# Epoch 4923: [Discriminator loss= 0.723102, Discriminator accuracy= 50.00%] [Generator loss= 0.838997]
# Epoch 4924: [Discriminator loss= 0.641923, Discriminator accuracy= 62.50%] [Generator loss= 0.821955]
# Epoch 4925: [Discriminator loss= 0.629373, Discriminator accuracy= 62.50%] [Generator loss= 0.844863]
# Epoch 4926: [Discriminator loss= 0.656801, Discriminator accuracy= 65.62%] [Generator loss= 0.923085]
# Epoch 4927: [Discriminator loss= 0.653735, Discriminator accuracy= 65.62%] [Generator loss= 0.869519]
# Epoch 4928: [Discriminator loss= 0.664842, Discriminator accuracy= 59.38%] [Generator loss= 0.858045]
# Epoch 4929: [Discriminator loss= 0.789310, Discriminator accuracy= 46.88%] [Generator loss= 0.915653]
# Epoch 4930: [Discriminator loss= 0.724139, Discriminator accuracy= 43.75%] [Generator loss= 0.941700]
# Epoch 4931: [Discriminator loss= 0.683444, Discriminator accuracy= 53.12%] [Generator loss= 0.913579]
# Epoch 4932: [Discriminator loss= 0.656907, Discriminator accuracy= 71.88%] [Generator loss= 0.901369]
# Epoch 4933: [Discriminator loss= 0.537093, Discriminator accuracy= 81.25%] [Generator loss= 0.919828]
# Epoch 4934: [Discriminator loss= 0.591439, Discriminator accuracy= 65.62%] [Generator loss= 0.893146]
# Epoch 4935: [Discriminator loss= 0.609694, Discriminator accuracy= 65.62%] [Generator loss= 0.869423]
# Epoch 4936: [Discriminator loss= 0.618404, Discriminator accuracy= 68.75%] [Generator loss= 0.838970]
# Epoch 4937: [Discriminator loss= 0.678928, Discriminator accuracy= 65.62%] [Generator loss= 0.914894]
# Epoch 4938: [Discriminator loss= 0.618649, Discriminator accuracy= 62.50%] [Generator loss= 0.847487]
# Epoch 4939: [Discriminator loss= 0.605875, Discriminator accuracy= 68.75%] [Generator loss= 0.844790]
# Epoch 4940: [Discriminator loss= 0.610737, Discriminator accuracy= 68.75%] [Generator loss= 0.837051]
# Epoch 4941: [Discriminator loss= 0.603763, Discriminator accuracy= 68.75%] [Generator loss= 0.834375]
# Epoch 4942: [Discriminator loss= 0.657488, Discriminator accuracy= 62.50%] [Generator loss= 0.796133]
# Epoch 4943: [Discriminator loss= 0.640166, Discriminator accuracy= 68.75%] [Generator loss= 0.903861]
# Epoch 4944: [Discriminator loss= 0.759665, Discriminator accuracy= 43.75%] [Generator loss= 0.847281]
# Epoch 4945: [Discriminator loss= 0.775963, Discriminator accuracy= 53.12%] [Generator loss= 0.854054]
# Epoch 4946: [Discriminator loss= 0.621317, Discriminator accuracy= 65.62%] [Generator loss= 0.809975]
# Epoch 4947: [Discriminator loss= 0.672417, Discriminator accuracy= 62.50%] [Generator loss= 0.850650]
# Epoch 4948: [Discriminator loss= 0.666362, Discriminator accuracy= 56.25%] [Generator loss= 0.866777]
# Epoch 4949: [Discriminator loss= 0.650198, Discriminator accuracy= 62.50%] [Generator loss= 0.801797]
# Epoch 4950: [Discriminator loss= 0.659835, Discriminator accuracy= 59.38%] [Generator loss= 0.928376]
# Epoch 4951: [Discriminator loss= 0.644792, Discriminator accuracy= 62.50%] [Generator loss= 0.937930]
# Epoch 4952: [Discriminator loss= 0.709387, Discriminator accuracy= 50.00%] [Generator loss= 0.995829]
# Epoch 4953: [Discriminator loss= 0.716008, Discriminator accuracy= 40.62%] [Generator loss= 0.932659]
# Epoch 4954: [Discriminator loss= 0.659734, Discriminator accuracy= 56.25%] [Generator loss= 0.876952]
# Epoch 4955: [Discriminator loss= 0.603574, Discriminator accuracy= 68.75%] [Generator loss= 0.867177]
# Epoch 4956: [Discriminator loss= 0.531617, Discriminator accuracy= 81.25%] [Generator loss= 0.916691]
# Epoch 4957: [Discriminator loss= 0.585895, Discriminator accuracy= 65.62%] [Generator loss= 0.898794]
# Epoch 4958: [Discriminator loss= 0.648309, Discriminator accuracy= 56.25%] [Generator loss= 0.875876]
# Epoch 4959: [Discriminator loss= 0.726976, Discriminator accuracy= 59.38%] [Generator loss= 0.846296]
# Epoch 4960: [Discriminator loss= 0.662079, Discriminator accuracy= 59.38%] [Generator loss= 0.875137]
# Epoch 4961: [Discriminator loss= 0.729547, Discriminator accuracy= 59.38%] [Generator loss= 0.854694]
# Epoch 4962: [Discriminator loss= 0.628606, Discriminator accuracy= 68.75%] [Generator loss= 0.849140]
# Epoch 4963: [Discriminator loss= 0.663184, Discriminator accuracy= 53.12%] [Generator loss= 0.920015]
# Epoch 4964: [Discriminator loss= 0.623688, Discriminator accuracy= 65.62%] [Generator loss= 0.988298]
# Epoch 4965: [Discriminator loss= 0.608404, Discriminator accuracy= 65.62%] [Generator loss= 1.086709]
# Epoch 4966: [Discriminator loss= 0.739230, Discriminator accuracy= 56.25%] [Generator loss= 1.022918]
# Epoch 4967: [Discriminator loss= 0.659099, Discriminator accuracy= 59.38%] [Generator loss= 0.886193]
# Epoch 4968: [Discriminator loss= 0.570254, Discriminator accuracy= 71.88%] [Generator loss= 0.873138]
# Epoch 4969: [Discriminator loss= 0.694708, Discriminator accuracy= 53.12%] [Generator loss= 0.908649]
# Epoch 4970: [Discriminator loss= 0.760990, Discriminator accuracy= 50.00%] [Generator loss= 0.799290]
# Epoch 4971: [Discriminator loss= 0.654150, Discriminator accuracy= 59.38%] [Generator loss= 0.846742]
# Epoch 4972: [Discriminator loss= 0.722237, Discriminator accuracy= 53.12%] [Generator loss= 0.807023]
# Epoch 4973: [Discriminator loss= 0.665237, Discriminator accuracy= 56.25%] [Generator loss= 0.888644]
# Epoch 4974: [Discriminator loss= 0.681925, Discriminator accuracy= 56.25%] [Generator loss= 1.012817]
# Epoch 4975: [Discriminator loss= 0.640278, Discriminator accuracy= 56.25%] [Generator loss= 0.906054]
# Epoch 4976: [Discriminator loss= 0.651522, Discriminator accuracy= 65.62%] [Generator loss= 0.894334]
# Epoch 4977: [Discriminator loss= 0.627694, Discriminator accuracy= 65.62%] [Generator loss= 0.827859]
# Epoch 4978: [Discriminator loss= 0.603393, Discriminator accuracy= 68.75%] [Generator loss= 0.921592]
# Epoch 4979: [Discriminator loss= 0.664486, Discriminator accuracy= 59.38%] [Generator loss= 0.933585]
# Epoch 4980: [Discriminator loss= 0.696870, Discriminator accuracy= 56.25%] [Generator loss= 0.933382]
# Epoch 4981: [Discriminator loss= 0.674556, Discriminator accuracy= 56.25%] [Generator loss= 0.928277]
# Epoch 4982: [Discriminator loss= 0.672590, Discriminator accuracy= 50.00%] [Generator loss= 0.877510]
# Epoch 4983: [Discriminator loss= 0.694478, Discriminator accuracy= 53.12%] [Generator loss= 0.953008]
# Epoch 4984: [Discriminator loss= 0.564723, Discriminator accuracy= 78.12%] [Generator loss= 0.846218]
# Epoch 4985: [Discriminator loss= 0.603170, Discriminator accuracy= 78.12%] [Generator loss= 0.875704]
# Epoch 4986: [Discriminator loss= 0.655954, Discriminator accuracy= 53.12%] [Generator loss= 0.828905]
# Epoch 4987: [Discriminator loss= 0.695549, Discriminator accuracy= 56.25%] [Generator loss= 0.878919]
# Epoch 4988: [Discriminator loss= 0.607089, Discriminator accuracy= 68.75%] [Generator loss= 0.780660]
# Epoch 4989: [Discriminator loss= 0.692468, Discriminator accuracy= 46.88%] [Generator loss= 0.851898]
# Epoch 4990: [Discriminator loss= 0.607009, Discriminator accuracy= 75.00%] [Generator loss= 0.955189]
# Epoch 4991: [Discriminator loss= 0.736918, Discriminator accuracy= 43.75%] [Generator loss= 0.955620]
# Epoch 4992: [Discriminator loss= 0.616167, Discriminator accuracy= 65.62%] [Generator loss= 0.962621]
# Epoch 4993: [Discriminator loss= 0.666203, Discriminator accuracy= 56.25%] [Generator loss= 0.848113]
# Epoch 4994: [Discriminator loss= 0.658764, Discriminator accuracy= 68.75%] [Generator loss= 0.793927]
# Epoch 4995: [Discriminator loss= 0.650647, Discriminator accuracy= 68.75%] [Generator loss= 0.795909]
# Epoch 4996: [Discriminator loss= 0.525448, Discriminator accuracy= 78.12%] [Generator loss= 0.830842]
# Epoch 4997: [Discriminator loss= 0.794562, Discriminator accuracy= 37.50%] [Generator loss= 0.799288]
# Epoch 4998: [Discriminator loss= 0.788945, Discriminator accuracy= 50.00%] [Generator loss= 0.872763]
# Epoch 4999: [Discriminator loss= 0.640412, Discriminator accuracy= 59.38%] [Generator loss= 0.789089]
# Epoch 5000: [Discriminator loss= 0.644264, Discriminator accuracy= 65.62%] [Generator loss= 0.940482]
